# %%
import pandas as pd
import numpy as np

# %%
data2016_to_load = "../Education/ACSDT1Y2016.B07009_data_with_overlays_2019-12-21T130141.csv"
metadata2016_to_load = "../Education/ACSDT1Y2016.B07009_metadata_2019-12-21T130141.csv"

fulldata2016 = pd.read_csv(data2016_to_load)
metadata2016 = pd.read_csv(metadata2016_to_load)

# %%
fulldata2016.head()
# Out:
#            GEO_ID                       NAME      B07009_001E  \
# 0              id       Geographic Area Name  Estimate!!Total
# 1  0500000US12103   Pinellas County, Florida           735561
# 2  0500000US12105       Polk County, Florida           461083
# 3  0500000US12107     Putnam County, Florida              NaN
# 4  0500000US12109  St. Johns County, Florida           166186
#
#               B07009_001M                                      B07009_002E  \
# 0  Margin of Error!!Total  Estimate!!Total!!Less than high school graduate
# 1                     152                                            69909
# 2                     461                                            72503
# 3                     NaN                                              NaN
# 4                    1205                                             7164
#
#                                          B07009_002M  \
# 0  Margin of Error!!Total!!Less than high school ...
# ...

# %%
data2016 = fulldata2016[['GEO_ID',"NAME","B07009_003E","B07009_004E","B07009_005E","B07009_006E","B07009_001E"]]

data2016 = data2016.rename(columns={"GEO_ID":"FIPS","NAME":"County",
                                        "B07009_002E":"Less Than High School Graduate",
                                        "B07009_003E":"High school graduate (includes equivalency)",
                                        "B07009_004E":"Some college or associate's degree",
                                        "B07009_005E":"Bachelor's degree",
                                        "B07009_006E":"Graduate or professional degree","B07009_001E":"Total"})

# %%
data2016.head()
# Out:
#              FIPS                     County  \
# 0              id       Geographic Area Name
# 1  0500000US12103   Pinellas County, Florida
# 2  0500000US12105       Polk County, Florida
# 3  0500000US12107     Putnam County, Florida
# 4  0500000US12109  St. Johns County, Florida
#
#          High school graduate (includes equivalency)  \
# 0  Estimate!!Total!!High school graduate (include...
# 1                                             206961
# 2                                             165401
# 3                                                NaN
# 4                                              35736
#
#                   Some college or associate's degree  \
# 0  Estimate!!Total!!Some college or associate's d...
# 1                                             243061
# 2                                             130424
# 3                                                NaN
# 4                                              52134
#
#                     Bachelor's degree  \
# ...

# %%
data2016=data2016.drop(index =0)

# %%
data2016=data2016.reset_index(drop=True)

# %%
data2016.head()
# Out:
#              FIPS                     County  \
# 0  0500000US12103   Pinellas County, Florida
# 1  0500000US12105       Polk County, Florida
# 2  0500000US12107     Putnam County, Florida
# 3  0500000US12109  St. Johns County, Florida
# 4  0500000US12111  St. Lucie County, Florida
#
#   High school graduate (includes equivalency)  \
# 0                                      206961
# 1                                      165401
# 2                                         NaN
# 3                                       35736
# 4                                       73041
#
#   Some college or associate's degree Bachelor's degree  \
# 0                             243061            141216
# 1                             130424             61445
# 2                                NaN               NaN
# 3                              52134             45345
# 4                              70865             30503
#
#   Graduate or professional degree   Total
# ...

# %%
countySplit = data2016["County"].str.split(", ", n = 1, expand = True)

# %%
countySplit.head()
# Out:
#                   0        1
# 0   Pinellas County  Florida
# 1       Polk County  Florida
# 2     Putnam County  Florida
# 3  St. Johns County  Florida
# 4  St. Lucie County  Florida

# %%
data2016["County"]= countySplit[0] 
data2016["State"]=countySplit[1]

# %%
data2016
# Out:
#                FIPS                   County  \
# 0    0500000US12103          Pinellas County
# 1    0500000US12105              Polk County
# 2    0500000US12107            Putnam County
# 3    0500000US12109         St. Johns County
# 4    0500000US12111         St. Lucie County
# 5    0500000US12113        Santa Rosa County
# 6    0500000US12115          Sarasota County
# 7    0500000US12117          Seminole County
# 8    0500000US12119            Sumter County
# 9    0500000US12127           Volusia County
# 10   0500000US12131            Walton County
# 11   0500000US13013            Barrow County
# 12   0500000US13015            Bartow County
# 13   0500000US13021              Bibb County
# 14   0500000US13031           Bulloch County
# 15   0500000US13045           Carroll County
# 16   0500000US13047           Catoosa County
# 17   0500000US13051           Chatham County
# 18   0500000US13057          Cherokee County
# 19   0500000US13059            Clarke County
# ...

# %%
countyDelete = data2016["County"].str.split(" ", n = 1, expand = True)

# %%
data2016["County"]= countyDelete[0] 
data2016["Delete"]=countyDelete[1]

# %%
data2016
# Out:
#                FIPS      County High school graduate (includes equivalency)  \
# 0    0500000US12103    Pinellas                                      206961
# 1    0500000US12105        Polk                                      165401
# 2    0500000US12107      Putnam                                         NaN
# 3    0500000US12109         St.                                       35736
# 4    0500000US12111         St.                                       73041
# 5    0500000US12113       Santa                                       31497
# 6    0500000US12115    Sarasota                                       99454
# 7    0500000US12117    Seminole                                       68705
# 8    0500000US12119      Sumter                                       35180
# 9    0500000US12127     Volusia                                      122815
# 10   0500000US12131      Walton                                       12158
# ...

# %%
data2016.drop(columns=['Delete'])
# Out:
#                FIPS      County High school graduate (includes equivalency)  \
# 0    0500000US12103    Pinellas                                      206961
# 1    0500000US12105        Polk                                      165401
# 2    0500000US12107      Putnam                                         NaN
# 3    0500000US12109         St.                                       35736
# 4    0500000US12111         St.                                       73041
# 5    0500000US12113       Santa                                       31497
# 6    0500000US12115    Sarasota                                       99454
# 7    0500000US12117    Seminole                                       68705
# 8    0500000US12119      Sumter                                       35180
# 9    0500000US12127     Volusia                                      122815
# 10   0500000US12131      Walton                                       12158
# ...

# %%
splitFIPS = data2016["FIPS"].str.split("US", n = 1, expand = True)

# %%
splitFIPS.head()
# Out:
#          0      1
# 0  0500000  12103
# 1  0500000  12105
# 2  0500000  12107
# 3  0500000  12109
# 4  0500000  12111

# %%
data2016["Delete"]= splitFIPS[0] 
data2016["FIPS"]=splitFIPS[1]

# %%
data2016.drop(columns=['Delete'], inplace = True)

# %%
data2016.insert(len(data2016.columns), 'Year', 2016)

# %%
data2016.dropna(inplace = True)

# %%
data2016.head()
# Out:
#     FIPS    County High school graduate (includes equivalency)  \
# 0  12103  Pinellas                                      206961
# 1  12105      Polk                                      165401
# 3  12109       St.                                       35736
# 4  12111       St.                                       73041
# 5  12113     Santa                                       31497
#
#   Some college or associate's degree Bachelor's degree  \
# 0                             243061            141216
# 1                             130424             61445
# 3                              52134             45345
# 4                              70865             30503
# 5                              43250             21101
#
#   Graduate or professional degree   Total    State  Year
# 0                           74414  735561  Florida  2016
# 1                           31310  461083  Florida  2016
# 3                           25807  166186  Florida  2016
# ...

# %%
path = '../dataPoints/education_2016_clean.xlsx'
data2016.to_excel(path,index=False)

# %%
year5_to_load = "../Education/5Year/ACSDT5Y2016.B06009_data_with_overlays_2020-01-06T222644.csv"
metadata5_to_load = "../Education/5Year/ACSDT5Y2016.B06009_metadata_2020-01-06T222644.csv"

year5 = pd.read_csv(year5_to_load)
metadata2016 = pd.read_csv(metadata5_to_load)

# %%
year5 = year5[['GEO_ID',"NAME","B06009_003E","B06009_004E","B06009_005E","B06009_006E","B06009_001E"]]

year5 = year5.rename(columns={"GEO_ID":"FIPS","NAME":"County",
                                        "B06009_002E":"Less Than High School Graduate",
                                        "B06009_003E":"High school graduate (includes equivalency)",
                                        "B06009_004E":"Some college or associate's degree",
                                        "B06009_005E":"Bachelor's degree",
                                        "B06009_006E":"Graduate or professional degree","B06009_001E":"Total"})

# %%
year5=year5.drop(index =0)

# %%
year5=year5.reset_index(drop=True)

# %%
year5.insert(len(year5.columns), 'Year', 2016)

# %%
countySplit = year5["County"].str.split(", ", n = 1, expand = True)

# %%
year5["County"]= countySplit[0] 
year5["State"]=countySplit[1]

# %%
countyDelete = year5["County"].str.split(" ", n = 1, expand = True)

# %%
year5["County"]= countyDelete[0] 
year5["Delete"]=countyDelete[1]

# %%
year5.drop(columns=['Delete'], inplace = True)

# %%
splitFIPS = year5["FIPS"].str.split("US", n = 1, expand = True)

# %%
year5["Delete"]= splitFIPS[0] 
year5["FIPS"]=splitFIPS[1]

# %%
year5.drop(columns=['Delete'], inplace = True)

# %%
year5 = year5[year5.County != 'United']

# %%
missing16=year5[~year5.FIPS.isin(data2016.FIPS)]
list(missing16.columns.values)
# Out:
# ['FIPS',
#  'County',
#  'High school graduate (includes equivalency)',
#  "Some college or associate's degree",
#  "Bachelor's degree",
#  'Graduate or professional degree',
#  'Total',
#  'Year',
#  'State']

# %%
missing16
# Out:
#        FIPS        County High school graduate (includes equivalency)  \
# 0     05015       Carroll                                        6804
# 1     05017        Chicot                                        3248
# 2     05019         Clark                                        4056
# 3     05021          Clay                                        4586
# 4     05023      Cleburne                                        7188
# 5     05025     Cleveland                                        2529
# 6     05027      Columbia                                        5901
# 7     05029        Conway                                        6140
# 9     05033      Crawford                                       16556
# 10    05035    Crittenden                                       11049
# 11    05037         Cross                                        5107
# 12    05039        Dallas                                        2640
# ...

# %%
missing16[missing16['County']=="Putnam"]
# Out:
#        FIPS  County High school graduate (includes equivalency)  \
# 373   12107  Putnam                                       19472
# 503   13237  Putnam                                        5896
# 672   17155  Putnam                                        1659
# 825   18133  Putnam                                       10335
# 1202  29171  Putnam                                        1378
# 1926  36079  Putnam                                       18806
# 2172  39137  Putnam                                        9544
# 3031  54079  Putnam                                       15255
#
#      Some college or associate's degree Bachelor's degree  \
# 373                               14012              4228
# 503                                4250              1898
# 672                                1574               403
# 825                                7907              2129
# 1202                               1025               424
# ...

# %%
years = (data2016,missing16)

# %%
merging16 = pd.concat(years)
# Out:
# C:\Users\dfire\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
merging16
# Out:
#      Bachelor's degree     County   FIPS Graduate or professional degree  \
# 0               141216   Pinellas  12103                           74414
# 1                61445       Polk  12105                           31310
# 3                45345        St.  12109                           25807
# 4                30503        St.  12111                           14643
# 5                21101      Santa  12113                           11886
# 6                66311   Sarasota  12115                           43942
# 7                77148   Seminole  12117                           41357
# 8                16704     Sumter  12119                           14862
# 9                61614    Volusia  12127                           32773
# 10                9337     Walton  12131                            4128
# 11                5625     Barrow  13013                            3651
# 12                9575     Bartow  13015                            3979
# ...

# %%
path = '../dataPoints/education_2016_merged.xlsx'
merging16.to_excel(path,index=False)
