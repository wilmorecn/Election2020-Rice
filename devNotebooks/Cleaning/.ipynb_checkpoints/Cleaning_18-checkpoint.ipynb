# %%
import pandas as pd
import numpy as np

# %%
data2018_to_load = "../Education/ACSDT1Y2018.B07009_data_with_overlays_2019-12-21T130141.csv"
metadata2018_to_load = "../Education/ACSDT1Y2018.B07009_metadata_2019-12-21T130141.csv"

fulldata2018 = pd.read_csv(data2018_to_load)
metadata2018 = pd.read_csv(metadata2018_to_load)

# %%
fulldata2018.head()
# Out:
#            GEO_ID                             NAME  \
# 0              id             Geographic Area Name
# 1  0500000US44005     Newport County, Rhode Island
# 2  0500000US44009  Washington County, Rhode Island
# 3  0500000US45073    Oconee County, South Carolina
# 4  0500000US48187          Guadalupe County, Texas
#
#                                          B07009_008M  \
# 0  Margin of Error!!Total!!Same house 1 year ago!...
# 1                                               1216
# 2                                               1019
# 3                                               2154
# 4                                               1772
#
#                                          B07009_009E  \
# 0  Estimate!!Total!!Same house 1 year ago!!High s...
# 1                                              10838
# 2                                              18699
# 3                                              13775
# 4                                              29977
#
# ...

# %%
data2018 = fulldata2018[['GEO_ID',"NAME","B07009_003E","B07009_004E","B07009_005E","B07009_006E","B07009_001E"]]

data2018 = data2018.rename(columns={"GEO_ID":"FIPS","NAME":"County",
                                        "B07009_002E":"Less Than High School Graduate",
                                        "B07009_003E":"High school graduate (includes equivalency)",
                                        "B07009_004E":"Some college or associate's degree",
                                        "B07009_005E":"Bachelor's degree",
                                        "B07009_006E":"Graduate or professional degree","B07009_001E":"Total"})

# %%
data2018.head()
# Out:
#              FIPS                           County  \
# 0              id             Geographic Area Name
# 1  0500000US44005     Newport County, Rhode Island
# 2  0500000US44009  Washington County, Rhode Island
# 3  0500000US45073    Oconee County, South Carolina
# 4  0500000US48187          Guadalupe County, Texas
#
#          High school graduate (includes equivalency)  \
# 0  Estimate!!Total!!High school graduate (include...
# 1                                              11420
# 2                                              19766
# 3                                              15646
# 4                                              34829
#
#                   Some college or associate's degree  \
# 0  Estimate!!Total!!Some college or associate's d...
# 1                                              14068
# 2                                              21277
# 3                                              17493
# 4                                              31801
#
# ...

# %%
data2018=data2018.drop(index =0)

# %%
data2018=data2018.reset_index(drop=True)

# %%
data2018.head()
# Out:
#              FIPS                           County  \
# 0  0500000US44005     Newport County, Rhode Island
# 1  0500000US44009  Washington County, Rhode Island
# 2  0500000US45073    Oconee County, South Carolina
# 3  0500000US48187          Guadalupe County, Texas
# 4  0500000US53061     Snohomish County, Washington
#
#   High school graduate (includes equivalency)  \
# 0                                       11420
# 1                                       19766
# 2                                       15646
# 3                                       34829
# 4                                      133029
#
#   Some college or associate's degree Bachelor's degree  \
# 0                              14068             16578
# 1                              21277             23157
# 2                              17493              9062
# 3                              31801             19914
# 4                             204426            125602
#
# ...

# %%
countySplit = data2018["County"].str.split(", ", n = 1, expand = True)

# %%
countySplit.head()
# Out:
#                    0               1
# 0     Newport County    Rhode Island
# 1  Washington County    Rhode Island
# 2      Oconee County  South Carolina
# 3   Guadalupe County           Texas
# 4   Snohomish County      Washington

# %%
data2018["County"]= countySplit[0] 
data2018["State"]=countySplit[1]

# %%
data2018
# Out:
#                FIPS               County  \
# 0    0500000US44005       Newport County
# 1    0500000US44009    Washington County
# 2    0500000US45073        Oconee County
# 3    0500000US48187     Guadalupe County
# 4    0500000US53061     Snohomish County
# 5    0500000US72113      Ponce Municipio
# 6    0500000US06085   Santa Clara County
# 7    0500000US06099    Stanislaus County
# 8    0500000US12099    Palm Beach County
# 9    0500000US13117       Forsyth County
# 10   0500000US20173      Sedgwick County
# 11   0500000US26005       Allegan County
# 12   0500000US26081          Kent County
# 13   0500000US29189     St. Louis County
# 14   0500000US34007        Camden County
# 15   0500000US35035         Otero County
# 16   0500000US37171         Surry County
# 17   0500000US47149    Rutherford County
# 18   0500000US48183         Gregg County
# 19   0500000US48347   Nacogdoches County
# 20   0500000US51069     Frederick County
# 21   0500000US55089       Ozaukee County
# ...

# %%
countyDelete = data2018["County"].str.split(" ", n = 1, expand = True)

# %%
data2018["County"]= countyDelete[0] 
data2018["Delete"]=countyDelete[1]

# %%
data2018
# Out:
#                FIPS        County High school graduate (includes equivalency)  \
# 0    0500000US44005       Newport                                       11420
# 1    0500000US44009    Washington                                       19766
# 2    0500000US45073        Oconee                                       15646
# 3    0500000US48187     Guadalupe                                       34829
# 4    0500000US53061     Snohomish                                      133029
# 5    0500000US72113         Ponce                                         NaN
# 6    0500000US06085         Santa                                      184686
# 7    0500000US06099    Stanislaus                                      107960
# 8    0500000US12099          Palm                                      265487
# 9    0500000US13117       Forsyth                                       26129
# 10   0500000US20173      Sedgwick                                       85703
# ...

# %%
data2018.drop(columns=['Delete'])
# Out:
#                FIPS        County High school graduate (includes equivalency)  \
# 0    0500000US44005       Newport                                       11420
# 1    0500000US44009    Washington                                       19766
# 2    0500000US45073        Oconee                                       15646
# 3    0500000US48187     Guadalupe                                       34829
# 4    0500000US53061     Snohomish                                      133029
# 5    0500000US72113         Ponce                                         NaN
# 6    0500000US06085         Santa                                      184686
# 7    0500000US06099    Stanislaus                                      107960
# 8    0500000US12099          Palm                                      265487
# 9    0500000US13117       Forsyth                                       26129
# 10   0500000US20173      Sedgwick                                       85703
# ...

# %%
splitFIPS = data2018["FIPS"].str.split("US", n = 1, expand = True)

# %%
splitFIPS.head()
# Out:
#          0      1
# 0  0500000  44005
# 1  0500000  44009
# 2  0500000  45073
# 3  0500000  48187
# 4  0500000  53061

# %%
data2018["Delete"]= splitFIPS[0] 
data2018["FIPS"]=splitFIPS[1]

# %%
data2018.drop(columns=['Delete'], inplace = True)

# %%
data2018.insert(len(data2018.columns), 'Year', 2018)

# %%
data2018.dropna(inplace = True)

# %%
data2018.head()
# Out:
#     FIPS      County High school graduate (includes equivalency)  \
# 0  44005     Newport                                       11420
# 1  44009  Washington                                       19766
# 2  45073      Oconee                                       15646
# 3  48187   Guadalupe                                       34829
# 4  53061   Snohomish                                      133029
#
#   Some college or associate's degree Bachelor's degree  \
# 0                              14068             16578
# 1                              21277             23157
# 2                              17493              9062
# 3                              31801             19914
# 4                             204426            125602
#
#   Graduate or professional degree   Total           State  Year
# 0                           14723   61616    Rhode Island  2018
# 1                           18154   87230    Rhode Island  2018
# ...

# %%
path = '../dataPoints/education_2018_clean.xlsx'
data2018.to_excel(path,index=False)

# %%
year5_to_load = "../Education/5Year/ACSDT5Y2018.B06009_data_with_overlays_2020-01-06T222644.csv"
metadata5_to_load = "../Education/5Year/ACSDT5Y2018.B06009_metadata_2020-01-06T222644.csv"

year5 = pd.read_csv(year5_to_load)
metadata2018 = pd.read_csv(metadata5_to_load)

# %%
year5 = year5[['GEO_ID',"NAME","B06009_003E","B06009_004E","B06009_005E","B06009_006E","B06009_001E"]]

year5 = year5.rename(columns={"GEO_ID":"FIPS","NAME":"County",
                                        "B06009_002E":"Less Than High School Graduate",
                                        "B06009_003E":"High school graduate (includes equivalency)",
                                        "B06009_004E":"Some college or associate's degree",
                                        "B06009_005E":"Bachelor's degree",
                                        "B06009_006E":"Graduate or professional degree","B06009_001E":"Total"})

# %%
year5=year5.drop(index =0)

# %%
year5=year5.reset_index(drop=True)

# %%
year5.insert(len(year5.columns), 'Year', 2018)

# %%
countySplit = year5["County"].str.split(", ", n = 1, expand = True)

# %%
year5["County"]= countySplit[0] 
year5["State"]=countySplit[1]

# %%
countyDelete = year5["County"].str.split(" ", n = 1, expand = True)

# %%
year5["County"]= countyDelete[0] 
year5["Delete"]=countyDelete[1]

# %%
year5.drop(columns=['Delete'], inplace = True)

# %%
splitFIPS = year5["FIPS"].str.split("US", n = 1, expand = True)

# %%
year5["Delete"]= splitFIPS[0] 
year5["FIPS"]=splitFIPS[1]

# %%
year5.drop(columns=['Delete'], inplace = True)

# %%
year5 = year5[year5.County != 'United']

# %%
missing18=year5[~year5.FIPS.isin(data2018.FIPS)]
list(missing18.columns.values)
# Out:
# ['FIPS',
#  'County',
#  'High school graduate (includes equivalency)',
#  "Some college or associate's degree",
#  "Bachelor's degree",
#  'Graduate or professional degree',
#  'Total',
#  'Year',
#  'State']

# %%
missing18
# Out:
#        FIPS        County High school graduate (includes equivalency)  \
# 0     28151    Washington                                        9254
# 1     28111         Perry                                        3290
# 2     28019       Choctaw                                        2201
# 3     28057      Itawamba                                        4743
# 4     28015       Carroll                                        2422
# 5     28043       Grenada                                        3963
# 6     28063     Jefferson                                        1808
# 7     28041        Greene                                        3463
# 8     28093      Marshall                                        9831
# 9     28119       Quitman                                        1489
# 10    28011       Bolivar                                        5141
# 11    28073         Lamar                                        9460
# ...

# %%
years = (data2018,missing18)

# %%
merging18 = pd.concat(years)
# Out:
# C:\Users\dfire\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
merging18
# Out:
#      Bachelor's degree       County   FIPS Graduate or professional degree  \
# 0                16578      Newport  44005                           14723
# 1                23157   Washington  44009                           18154
# 2                 9062       Oconee  45073                            5597
# 3                19914    Guadalupe  48187                            9797
# 4               125602    Snohomish  53061                           60282
# 6               383232        Santa  06085                          342615
# 7                39921   Stanislaus  06099                           18053
# 8               247498         Palm  12099                          154919
# 9                52519      Forsyth  13117                           31637
# 10               65348     Sedgwick  20173                           40647
# 11               11268      Allegan  26005                            7379
# ...

# %%
path = '../dataPoints/education_2018_merged.xlsx'
merging18.to_excel(path,index=False)
