# %%
import pandas as pd
import numpy as np

# %%
data2012_to_load = "../Education/ACSDT1Y2012.B07009_data_with_overlays_2019-12-21T130141.csv"
metadata2012_to_load = "../Education/ACSDT1Y2012.B07009_metadata_2019-12-21T130141.csv"

fulldata2012 = pd.read_csv(data2012_to_load)
metadata2012 = pd.read_csv(metadata2012_to_load)

# %%
fulldata2012.head()
# Out:
#            GEO_ID                          NAME      B07009_001E  \
# 0              id          Geographic Area Name  Estimate!!Total
# 1  0500000US27013  Blue Earth County, Minnesota            38076
# 2  0500000US27019      Carver County, Minnesota            59992
# 3  0500000US27037      Dakota County, Minnesota           271925
# 4  0500000US27053    Hennepin County, Minnesota           807164
#
#               B07009_001M                                      B07009_002E  \
# 0  Margin of Error!!Total  Estimate!!Total!!Less than high school graduate
# 1                     349                                             1910
# 2                     598                                             3283
# 3                     804                                            14490
# 4                     355                                            59364
#
#                                          B07009_002M  \
# 0  Margin of Error!!Total!!Less than high school ...
# ...

# %%
data2012 = fulldata2012[['GEO_ID',"NAME","B07009_003E","B07009_004E","B07009_005E","B07009_006E","B07009_001E"]]

data2012 = data2012.rename(columns={"GEO_ID":"FIPS","NAME":"County",
                                        "B07009_002E":"Less Than High School Graduate",
                                        "B07009_003E":"High school graduate (includes equivalency)",
                                        "B07009_004E":"Some college or associate's degree",
                                        "B07009_005E":"Bachelor's degree",
                                        "B07009_006E":"Graduate or professional degree","B07009_001E":"Total"})

# %%
data2012.head()
# Out:
#              FIPS                        County  \
# 0              id          Geographic Area Name
# 1  0500000US27013  Blue Earth County, Minnesota
# 2  0500000US27019      Carver County, Minnesota
# 3  0500000US27037      Dakota County, Minnesota
# 4  0500000US27053    Hennepin County, Minnesota
#
#          High school graduate (includes equivalency)  \
# 0  Estimate!!Total!!High school graduate (include...
# 1                                              10872
# 2                                              12971
# 3                                              58194
# 4                                             147072
#
#                   Some college or associate's degree  \
# 0  Estimate!!Total!!Some college or associate's d...
# 1                                              12539
# 2                                              17609
# 3                                              93310
# 4                                             222575
#
# ...

# %%
data2012=data2012.drop(index =0)

# %%
data2012=data2012.reset_index(drop=True)

# %%
data2012.head()
# Out:
#              FIPS                        County  \
# 0  0500000US27013  Blue Earth County, Minnesota
# 1  0500000US27019      Carver County, Minnesota
# 2  0500000US27037      Dakota County, Minnesota
# 3  0500000US27053    Hennepin County, Minnesota
# 4  0500000US27109     Olmsted County, Minnesota
#
#   High school graduate (includes equivalency)  \
# 0                                       10872
# 1                                       12971
# 2                                       58194
# 3                                      147072
# 4                                       20925
#
#   Some college or associate's degree Bachelor's degree  \
# 0                              12539              8641
# 1                              17609             18650
# 2                              93310             75188
# 3                             222575            245622
# 4                              32675             24558
#
#   Graduate or professional degree   Total
# ...

# %%
countySplit = data2012["County"].str.split(", ", n = 1, expand = True)

# %%
countySplit.head()
# Out:
#                    0          1
# 0  Blue Earth County  Minnesota
# 1      Carver County  Minnesota
# 2      Dakota County  Minnesota
# 3    Hennepin County  Minnesota
# 4     Olmsted County  Minnesota

# %%
data2012["County"]= countySplit[0] 
data2012["State"]=countySplit[1]

# %%
data2012
# Out:
#                FIPS                   County  \
# 0    0500000US27013        Blue Earth County
# 1    0500000US27019            Carver County
# 2    0500000US27037            Dakota County
# 3    0500000US27053          Hennepin County
# 4    0500000US27109           Olmsted County
# 5    0500000US27123            Ramsey County
# 6    0500000US27137         St. Louis County
# 7    0500000US27139             Scott County
# 8    0500000US27141         Sherburne County
# 9    0500000US27145           Stearns County
# 10   0500000US27163        Washington County
# 11   0500000US27171            Wright County
# 12   0500000US28033            DeSoto County
# 13   0500000US28035           Forrest County
# 14   0500000US28047          Harrison County
# 15   0500000US28049             Hinds County
# 16   0500000US28059           Jackson County
# 17   0500000US28067             Jones County
# 18   0500000US28075        Lauderdale County
# 19   0500000US28081               Lee County
# ...

# %%
countyDelete = data2012["County"].str.split(" ", n = 1, expand = True)

# %%
data2012["County"]= countyDelete[0] 
data2012["Delete"]=countyDelete[1]

# %%
data2012
# Out:
#                FIPS      County High school graduate (includes equivalency)  \
# 0    0500000US27013        Blue                                       10872
# 1    0500000US27019      Carver                                       12971
# 2    0500000US27037      Dakota                                       58194
# 3    0500000US27053    Hennepin                                      147072
# 4    0500000US27109     Olmsted                                       20925
# 5    0500000US27123      Ramsey                                       77198
# 6    0500000US27137         St.                                       40987
# 7    0500000US27139       Scott                                       19420
# 8    0500000US27141   Sherburne                                         NaN
# 9    0500000US27145     Stearns                                       28745
# 10   0500000US27163  Washington                                       34418
# ...

# %%
data2012.drop(columns=['Delete'])
# Out:
#                FIPS      County High school graduate (includes equivalency)  \
# 0    0500000US27013        Blue                                       10872
# 1    0500000US27019      Carver                                       12971
# 2    0500000US27037      Dakota                                       58194
# 3    0500000US27053    Hennepin                                      147072
# 4    0500000US27109     Olmsted                                       20925
# 5    0500000US27123      Ramsey                                       77198
# 6    0500000US27137         St.                                       40987
# 7    0500000US27139       Scott                                       19420
# 8    0500000US27141   Sherburne                                         NaN
# 9    0500000US27145     Stearns                                       28745
# 10   0500000US27163  Washington                                       34418
# ...

# %%
splitFIPS = data2012["FIPS"].str.split("US", n = 1, expand = True)

# %%
splitFIPS.head()
# Out:
#          0      1
# 0  0500000  27013
# 1  0500000  27019
# 2  0500000  27037
# 3  0500000  27053
# 4  0500000  27109

# %%
data2012["Delete"]= splitFIPS[0] 
data2012["FIPS"]=splitFIPS[1]

# %%
data2012.drop(columns=['Delete'], inplace = True)

# %%
data2012.insert(len(data2012.columns), 'Year', 2012)

# %%
data2012.dropna(inplace = True)

# %%
data2012.head()
# Out:
#     FIPS    County High school graduate (includes equivalency)  \
# 0  27013      Blue                                       10872
# 1  27019    Carver                                       12971
# 2  27037    Dakota                                       58194
# 3  27053  Hennepin                                      147072
# 4  27109   Olmsted                                       20925
#
#   Some college or associate's degree Bachelor's degree  \
# 0                              12539              8641
# 1                              17609             18650
# 2                              93310             75188
# 3                             222575            245622
# 4                              32675             24558
#
#   Graduate or professional degree   Total      State  Year
# 0                            4114   38076  Minnesota  2012
# 1                            7479   59992  Minnesota  2012
# 2                           30743  271925  Minnesota  2012
# ...

# %%
path = '../dataPoints/education_2012_clean.xlsx'
data2012.to_excel(path,index=False)

# %%
data2012.dtypes
# Out:
# FIPS                                           object
# County                                         object
# High school graduate (includes equivalency)    object
# Some college or associate's degree             object
# Bachelor's degree                              object
# Graduate or professional degree                object
# Total                                          object
# State                                          object
# Year                                            int64
# dtype: object

# %%
year5_to_load = "../Education/5Year/ACSDT5Y2012.B06009_data_with_overlays_2020-01-06T222644.csv"
metadata5_to_load = "../Education/5Year/ACSDT5Y2012.B06009_metadata_2020-01-06T222644.csv"

year5 = pd.read_csv(year5_to_load)
metadata2012 = pd.read_csv(metadata5_to_load)

# %%
year5 = year5[['GEO_ID',"NAME","B06009_003E","B06009_004E","B06009_005E","B06009_006E","B06009_001E"]]

year5 = year5.rename(columns={"GEO_ID":"FIPS","NAME":"County",
                                        "B06009_002E":"Less Than High School Graduate",
                                        "B06009_003E":"High school graduate (includes equivalency)",
                                        "B06009_004E":"Some college or associate's degree",
                                        "B06009_005E":"Bachelor's degree",
                                        "B06009_006E":"Graduate or professional degree","B06009_001E":"Total"})

# %%
year5=year5.drop(index =0)

# %%
year5=year5.reset_index(drop=True)

# %%
year5.insert(len(year5.columns), 'Year', 2012)

# %%
countySplit = year5["County"].str.split(", ", n = 1, expand = True)

# %%
year5["County"]= countySplit[0] 
year5["State"]=countySplit[1]

# %%
countyDelete = year5["County"].str.split(" ", n = 1, expand = True)

# %%
year5["County"]= countyDelete[0] 
year5["Delete"]=countyDelete[1]

# %%
year5.drop(columns=['Delete'], inplace = True)

# %%
splitFIPS = year5["FIPS"].str.split("US", n = 1, expand = True)

# %%
year5["Delete"]= splitFIPS[0] 
year5["FIPS"]=splitFIPS[1]

# %%
year5.drop(columns=['Delete'], inplace = True)

# %%
year5 = year5[year5.County != 'United']

# %%
missing12=year5[~year5.FIPS.isin(data2012.FIPS)]
list(missing12.columns.values)
# Out:
# ['FIPS',
#  'County',
#  'High school graduate (includes equivalency)',
#  "Some college or associate's degree",
#  "Bachelor's degree",
#  'Graduate or professional degree',
#  'Total',
#  'Year',
#  'State']

# %%
missing12
# Out:
#        FIPS     County High school graduate (includes equivalency)  \
# 0     01001    Autauga                                       11874
# 2     01005    Barbour                                        6320
# 3     01007       Bibb                                        6457
# 4     01009     Blount                                       13994
# 5     01011    Bullock                                        2729
# 6     01013     Butler                                        5463
# 8     01017   Chambers                                        8277
# 9     01019   Cherokee                                        6206
# 10    01021    Chilton                                       11356
# 11    01023    Choctaw                                        3683
# 12    01025     Clarke                                        7122
# 13    01027       Clay                                        3696
# 14    01029   Cleburne                                        3871
# ...

# %%
years = (data2012,missing12)

# %%
merging12 = pd.concat(years)
# Out:
# C:\Users\dfire\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
merging12
# Out:
#      Bachelor's degree      County   FIPS Graduate or professional degree  \
# 0                 8641        Blue  27013                            4114
# 1                18650      Carver  27019                            7479
# 2                75188      Dakota  27037                           30743
# 3               245622    Hennepin  27053                          132531
# 4                24558     Olmsted  27109                           14690
# 5                80611      Ramsey  27123                           53376
# 6                24920         St.  27137                           11809
# 7                26406       Scott  27139                            8652
# 9                15921     Stearns  27145                            8176
# 10               45386  Washington  27163                           23666
# 11               17023      Wright  27171                            4345
# 12               15546      DeSoto  28033                            7663
# ...

# %%
path = '../dataPoints/education_2012_merged.xlsx'
merging12.to_excel(path,index=False)
