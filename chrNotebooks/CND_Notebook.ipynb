# %%
import pandas as pd
import numpy as np

# %%
edemog2008_to_load = "Demographics/election_yr2008demog2.csv"
edemog2012_to_load = "Demographics/election_yr2012demog2.csv"
edemog2016_to_load = "Demographics/election_yr2016demog2.csv"
edemog2020_to_load = "Demographics/election_yr2020demog2.csv"
ACS2008_to_load = "Demographics/ACS_2008_5yr2.csv"
ACS2012_to_load = "Demographics/ACS_2012_5yr2.csv"
ACS2016_to_load = "Demographics/ACS_2016_5yr2.csv"
ElectionData_to_load = "Demographics/countypres_2000-2016_processed.csv"
Election2008_to_load = "Demographics/countypres_2008_processed.csv"
Election2012_to_load = "Demographics/countypres_2012_processed.csv"
Election2016_to_load = "Demographics/countypres_2016_processed.csv"

# %%
edemog2008 = pd.read_csv(edemog2008_to_load)
edemog2012 = pd.read_csv(edemog2012_to_load)
edemog2016 = pd.read_csv(edemog2016_to_load)
edemog2020 = pd.read_csv(edemog2020_to_load)
ACS2008 = pd.read_csv(ACS2008_to_load)
ACS2012 = pd.read_csv(ACS2012_to_load)
ACS2016 = pd.read_csv(ACS2016_to_load)
ElectionData = pd.read_csv(ElectionData_to_load)
Election2008 = pd.read_csv(Election2008_to_load)
Election2012 = pd.read_csv(Election2012_to_load)
Election2016 = pd.read_csv(Election2016_to_load)

# %%
ElectionData
# Out:
#       FIPS    state       county  year   FIPS/Year  totalvotes  \
# 0     1001  Alabama      Autauga  2008  2008/01001       23641
# 1     1003  Alabama      Baldwin  2008  2008/01003       81413
# 2     1005  Alabama      Barbour  2008  2008/01005       11630
# 3     1007  Alabama         Bibb  2008  2008/01007        8644
# 4     1009  Alabama       Blount  2008  2008/01009       24267
# ...    ...      ...          ...   ...         ...         ...
# 9460  2037   Alaska  District 37  2016  2016/02037        5062
# 9461  2038   Alaska  District 38  2016  2016/02038        5095
# 9462  2039   Alaska  District 39  2016  2016/02039        5639
# 9463  2040   Alaska  District 40  2016  2016/02040        4610
# 9464  2099   Alaska  District 99  2016  2016/02099        5056
#
#       dem_vote_share  rep_vote_share  other_vote_share winning_party  \
# 0           0.257730        0.736136          0.006133    Republican
# ...

# %% [markdown]
# # 2008

# %%
edemog2008.head()
# Out:
#    Year  FIPS             Name of Area          Qualifying Name  \
# 0  2008  1003  Baldwin County, Alabama  Baldwin County, Alabama
# 1  2008  1015  Calhoun County, Alabama  Calhoun County, Alabama
# 2  2008  1043  Cullman County, Alabama  Cullman County, Alabama
# 3  2008  1049   DeKalb County, Alabama   DeKalb County, Alabama
# 4  2008  1051   Elmore County, Alabama   Elmore County, Alabama
#
#   State/U.S.-Abbreviation (USPS)  Summary Level  Geographic Component  \
# 0                             al             50                     0
# 1                             al             50                     0
# 2                             al             50                     0
# 3                             al             50                     0
# 4                             al             50                     0
#
#   File Identification  Logical Record Number  State (FIPS)  ...  \
# 0               ACSSF                     13             1  ...
# ...

# %%
list(edemog2008.columns.values)
# Out:
# ['Year',
#  'FIPS',
#  'Name of Area',
#  'Qualifying Name',
#  'State/U.S.-Abbreviation (USPS)',
#  'Summary Level',
#  'Geographic Component',
#  'File Identification',
#  'Logical Record Number',
#  'State (FIPS)',
#  'County',
#  'Geographic Identifier',
#  'Area (Land)',
#  'Area (Water)',
#  'Area Total:',
#  'Area Total: Area (Land)',
#  'Area Total: Area (Water)',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Total Population: Male',
#  'Total Population: Female',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  'Total Population: Under 18 Years',
#  'Total Population: 18 to 34 Years',
#  'Total Population: 35 to 64 Years',
#  'Total Population: 65 and Over',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  'Total Population: White Alone',
# ...

# %%
#drop columns
edemog2008.drop(columns=['Qualifying Name','Summary Level',
 'Geographic Component',
 'File Identification',
 'Logical Record Number',
 'State (FIPS)',
 'County',
 'Geographic Identifier','Area (Land)',
 'Area (Water)','Area Total: Area (Land)',
 'Area Total: Area (Water)','Total Population: Male',
 'Total Population: Female','Total Population: Under 18 Years',
 'Total Population: 18 to 34 Years',
 'Total Population: 35 to 64 Years',
 'Total Population: 65 and Over','Total Population: White Alone',
 'Total Population: Black or African American Alone',
 'Total Population: American Indian and Alaska Native Alone',
 'Total Population: Asian Alone',
 'Total Population: Native Hawaiian and Other Pacific Islander Alone',
 'Total Population: Some Other Race Alone',
 'Total Population: Two or More Races','Population 15 Years and Over:',
 'Population 15 Years and Over: Never Married',
 'Population 15 Years and Over: Now Married (Not Including Separated)',
 'Population 15 Years and Over: Separated',
 'Population 15 Years and Over: Widowed',
 'Population 15 Years and Over: Divorced','Households: Family Households',
 'Households: Family Households: Married-Couple Family',
 'Households: Family Households: Other Family',
 'Households: Family Households: Other Family: Male Householder, No Wife Present',
 'Households: Family Households: Other Family: Female Householder, No Husband Present',
 'Households: Nonfamily Households',
 'Households: Nonfamily Households: Male Householder',
 'Households: Nonfamily Households: Female Householder','Occupied Housing Units: 1-Person Household',
 'Occupied Housing Units: 2-Person Household',
 'Occupied Housing Units: 3-Person Household',
 'Occupied Housing Units: 4-Person Household',
 'Occupied Housing Units: 5-Person Household',
 'Occupied Housing Units: 6-Person Household',
 'Occupied Housing Units: 7-or-More Person Household','Households: Unmarried-Partner Households',
 'Households: Unmarried-Partner Households: Same Sex Partners',
 'Households: Unmarried-Partner Households: Same Sex Partners: Male Householder and Male Partner',
 'Households: Unmarried-Partner Households: Same Sex Partners: Female Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Male Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Female Householder and Male Partner',
 'Households: All Other Households','Occupied Housing Units.1','Civilian Population 18 Years and Over: Veteran',
 'Civilian Population 18 Years and Over: Veteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Veteran: 65 Years and Over',
 'Civilian Population 18 Years and Over: Nonveteran',
 'Civilian Population 18 Years and Over: Nonveteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Nonveteran: 65 Years and Over','Civilian Veterans 18 Years and Over:',
 'Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 'Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 'Civilian Veterans 18 Years and Over: Vietnam Era Only',
 'Civilian Veterans 18 Years and Over: Korean War Only',
 'Civilian Veterans 18 Years and Over: World War Ii Only',
 'Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 'Civilian Veterans 18 Years and Over: Other Service',
 '% Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 '% Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 '% Civilian Veterans 18 Years and Over: Vietnam Era Only',
 '% Civilian Veterans 18 Years and Over: Korean War Only',
 '% Civilian Veterans 18 Years and Over: World War Ii Only',
 '% Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 '% Civilian Veterans 18 Years and Over: Other Service'], inplace = True)

# %%
#Rename column
edemog2008.rename(columns={'Year':'year'}, inplace = True)

# %%
edemog2008.head()
# Out:
#    year  FIPS             Name of Area State/U.S.-Abbreviation (USPS)  \
# 0  2008  1003  Baldwin County, Alabama                             al
# 1  2008  1015  Calhoun County, Alabama                             al
# 2  2008  1043  Cullman County, Alabama                             al
# 3  2008  1049   DeKalb County, Alabama                             al
# 4  2008  1051   Elmore County, Alabama                             al
#
#    Area Total:  % Area Total: Area (Land)  % Area Total: Area (Water)  \
# 0  2026.929040                      78.76                       21.24
# 1   612.321007                      99.37                        0.63
# 2   754.820853                      97.83                        2.17
# 3   778.649656                      99.91                        0.09
# 4   657.212311                      94.53                        5.47
#
#    Total Population  Population Density (Per Sq. Mile)  \
# 0            174439                         109.273882
# ...

# %%
list(ACS2008.columns.values)
# Out:
# ['year',
#  'FIPS',
#  'Name of Area',
#  'Qualifying Name',
#  'State/U.S.-Abbreviation (USPS)',
#  'Summary Level',
#  'Geographic Component',
#  'File Identification',
#  'Logical Record Number',
#  'State (FIPS)',
#  'County',
#  'Geographic Identifier',
#  'Area (Land)',
#  'Area (Water)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Area Total:',
#  'Area Total: Area (Land)',
#  'Area Total: Area (Water)',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  'Total Population: Male',
#  'Total Population: Female',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  'Total Population: Under 18 Years',
#  'Total Population: 18 to 34 Years',
#  'Total Population: 35 to 64 Years',
#  'Total Population: 65 and Over',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  'Total Population: White Alone',
# ...

# %%
#drop columns
ACS2008.drop(columns=['Qualifying Name','Summary Level',
 'Geographic Component',
 'File Identification',
 'Logical Record Number',
 'State (FIPS)',
 'County',
 'Geographic Identifier',
 'Area (Land)',
 'Area (Water)','Area Total: Area (Land)',
 'Area Total: Area (Water)','Total Population: Male',
 'Total Population: Female','Total Population: Under 18 Years',
 'Total Population: 18 to 34 Years',
 'Total Population: 35 to 64 Years',
 'Total Population: 65 and Over','Total Population: White Alone',
 'Total Population: Black or African American Alone',
 'Total Population: American Indian and Alaska Native Alone',
 'Total Population: Asian Alone',
 'Total Population: Native Hawaiian and Other Pacific Islander Alone',
 'Total Population: Some Other Race Alone',
 'Total Population: Two or More Races','Households: Family Households',
 'Households: Family Households: Married-Couple Family',
 'Households: Family Households: Other Family',
 'Households: Family Households: Other Family: Male Householder, No Wife Present',
 'Households: Family Households: Other Family: Female Householder, No Husband Present',
 'Households: Nonfamily Households',
 'Households: Nonfamily Households: Male Householder',
 'Households: Nonfamily Households: Female Householder','Occupied Housing Units: 1-Person Household',
 'Occupied Housing Units: 2-Person Household',
 'Occupied Housing Units: 3-Person Household',
 'Occupied Housing Units: 4-Person Household',
 'Occupied Housing Units: 5-Person Household',
 'Occupied Housing Units: 6-Person Household',
 'Occupied Housing Units: 7-or-More Person Household','Population 15 Years and Over:',
 'Population 15 Years and Over: Never Married',
 'Population 15 Years and Over: Now Married (Not Including Separated)',
 'Population 15 Years and Over: Separated',
 'Population 15 Years and Over: Widowed',
 'Population 15 Years and Over: Divorced','Households: Unmarried-Partner Households',
 'Households: Unmarried-Partner Households: Same Sex Partners',
 'Households: Unmarried-Partner Households: Same Sex Partners: Male Householder and Male Partner',
 'Households: Unmarried-Partner Households: Same Sex Partners: Female Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Male Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Female Householder and Male Partner',
 'Households: All Other Households','Population 25 Years and Over:',
 'Population 25 Years and Over: Less than High School',
 'Population 25 Years and Over: High School Graduate (Includes Equivalency)',
 'Population 25 Years and Over: Some College',
 "Population 25 Years and Over: Bachelor's Degree",
 "Population 25 Years and Over: Master's Degree",
 'Population 25 Years and Over: Professional School Degree',
 'Population 25 Years and Over: Doctorate Degree',
 '% Population 25 Years and Over: Less than High School',
 '% Population 25 Years and Over: High School Graduate (Includes Equivalency)',
 '% Population 25 Years and Over: Some College',
 "% Population 25 Years and Over: Bachelor's Degree",
 "% Population 25 Years and Over: Master's Degree",
 '% Population 25 Years and Over: Professional School Degree',
 '% Population 25 Years and Over: Doctorate Degree',
 'Occupied Housing Units.1',
 'Occupied Housing Units: Less than High School Graduate',
 'Occupied Housing Units: High School Graduate (Including Equivalency)',
 "Occupied Housing Units: Some College or Associate's Degree",
 "Occupied Housing Units: Bachelor's Degree or Higher",'Civilian Population 18 Years and Over:','% Occupied Housing Units: Less than High School Graduate',
 '% Occupied Housing Units: High School Graduate (Including Equivalency)',
 "% Occupied Housing Units: Some College or Associate's Degree",
 "% Occupied Housing Units: Bachelor's Degree or Higher",
 'Civilian Population 18 Years and Over: Veteran',
 'Civilian Population 18 Years and Over: Veteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Veteran: 65 Years and Over',
 'Civilian Population 18 Years and Over: Nonveteran',
 'Civilian Population 18 Years and Over: Nonveteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Nonveteran: 65 Years and Over','Civilian Veterans 18 Years and Over:',
 'Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 'Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 'Civilian Veterans 18 Years and Over: Vietnam Era Only',
 'Civilian Veterans 18 Years and Over: Korean War Only',
 'Civilian Veterans 18 Years and Over: World War Ii Only',
 'Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 'Civilian Veterans 18 Years and Over: Other Service',
 '% Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 '% Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 '% Civilian Veterans 18 Years and Over: Vietnam Era Only',
 '% Civilian Veterans 18 Years and Over: Korean War Only',
 '% Civilian Veterans 18 Years and Over: World War Ii Only',
 '% Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 '% Civilian Veterans 18 Years and Over: Other Service'], inplace=True)

# %%
ACS2008
# Out:
#       year   FIPS                      Name of Area  \
# 0     2008   1001           Autauga County, Alabama
# 1     2008   1003           Baldwin County, Alabama
# 2     2008   1005           Barbour County, Alabama
# 3     2008   1007              Bibb County, Alabama
# 4     2008   1009            Blount County, Alabama
# ...    ...    ...                               ...
# 3216  2008  72145  Vega Baja Municipio, Puerto Rico
# 3217  2008  72147    Vieques Municipio, Puerto Rico
# 3218  2008  72149   Villalba Municipio, Puerto Rico
# 3219  2008  72151    Yabucoa Municipio, Puerto Rico
# 3220  2008  72153      Yauco Municipio, Puerto Rico
#
#      State/U.S.-Abbreviation (USPS)  Total Population  \
# 0                                al             54590
# 1                                al            183226
# 2                                al             27469
# 3                                al             22769
# 4                                al             57466
# ...

# %%
#filling missing counties using 5yr file
missing2008=ACS2008[~ACS2008.FIPS.isin(edemog2008.FIPS)]
list(missing2008.columns.values)
# Out:
# ['year',
#  'FIPS',
#  'Name of Area',
#  'State/U.S.-Abbreviation (USPS)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Area Total:',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  '% Total Population: White Alone',
#  '% Total Population: Black or African American Alone',
#  '% Total Population: American Indian and Alaska Native Alone',
#  '% Total Population: Asian Alone',
#  '% Total Population: Native Hawaiian and Other Pacific Islander Alone',
#  '% Total Population: Some Other Race Alone',
#  '% Total Population: Two or More Races',
#  'Households:',
#  '% Households: Family Households',
#  '% Households: Family Households: Married-Couple Family',
#  '% Households: Family Households: Other Family',
# ...

# %%
missing2008
# Out:
#       year   FIPS                      Name of Area  \
# 0     2008   1001           Autauga County, Alabama
# 2     2008   1005           Barbour County, Alabama
# 3     2008   1007              Bibb County, Alabama
# 4     2008   1009            Blount County, Alabama
# 5     2008   1011           Bullock County, Alabama
# ...    ...    ...                               ...
# 3216  2008  72145  Vega Baja Municipio, Puerto Rico
# 3217  2008  72147    Vieques Municipio, Puerto Rico
# 3218  2008  72149   Villalba Municipio, Puerto Rico
# 3219  2008  72151    Yabucoa Municipio, Puerto Rico
# 3220  2008  72153      Yauco Municipio, Puerto Rico
#
#      State/U.S.-Abbreviation (USPS)  Total Population  \
# 0                                al             54590
# 2                                al             27469
# 3                                al             22769
# 4                                al             57466
# 5                                al             10779
# ...

# %%
#append missing 2008 with cleaned demog2008
edemog2008_final=pd.concat([edemog2008,missing2008], sort=False)
edemog2008_final.sort_values(by=['FIPS'])
#reset index
edemog2008_final=edemog2008_final.reset_index(drop=True)

edemog2008_final
# Out:
#       year   FIPS                      Name of Area  \
# 0     2008   1003           Baldwin County, Alabama
# 1     2008   1015           Calhoun County, Alabama
# 2     2008   1043           Cullman County, Alabama
# 3     2008   1049            DeKalb County, Alabama
# 4     2008   1051            Elmore County, Alabama
# ...    ...    ...                               ...
# 3216  2008  72145  Vega Baja Municipio, Puerto Rico
# 3217  2008  72147    Vieques Municipio, Puerto Rico
# 3218  2008  72149   Villalba Municipio, Puerto Rico
# 3219  2008  72151    Yabucoa Municipio, Puerto Rico
# 3220  2008  72153      Yauco Municipio, Puerto Rico
#
#      State/U.S.-Abbreviation (USPS)  Area Total:  % Area Total: Area (Land)  \
# 0                                al  2026.929040                      78.76
# 1                                al   612.321007                      99.37
# 2                                al   754.820853                      97.83
# ...

# %% [markdown]
# # 2012

# %%
edemog2012.head()
# Out:
#    Year  FIPS             Name of Area          Qualifying Name  \
# 0  2012  1003  Baldwin County, Alabama  Baldwin County, Alabama
# 1  2012  1015  Calhoun County, Alabama  Calhoun County, Alabama
# 2  2012  1043  Cullman County, Alabama  Cullman County, Alabama
# 3  2012  1049   DeKalb County, Alabama   DeKalb County, Alabama
# 4  2012  1051   Elmore County, Alabama   Elmore County, Alabama
#
#   State/U.S.-Abbreviation (USPS)  Summary Level  Geographic Component  \
# 0                             al             50                     0
# 1                             al             50                     0
# 2                             al             50                     0
# 3                             al             50                     0
# 4                             al             50                     0
#
#   File Identification  Logical Record Number  State (FIPS)  ...  \
# 0               ACSSF                     13             1  ...
# ...

# %%
list(edemog2012.columns.values)
# Out:
# ['Year',
#  'FIPS',
#  'Name of Area',
#  'Qualifying Name',
#  'State/U.S.-Abbreviation (USPS)',
#  'Summary Level',
#  'Geographic Component',
#  'File Identification',
#  'Logical Record Number',
#  'State (FIPS)',
#  'County',
#  'Geographic Identifier',
#  'Area (Land)',
#  'Area (Water)',
#  'Area Total:',
#  'Area Total: Area (Land)',
#  'Area Total: Area (Water)',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Total Population: Male',
#  'Total Population: Female',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  'Total Population: Under 18 Years',
#  'Total Population: 18 to 34 Years',
#  'Total Population: 35 to 64 Years',
#  'Total Population: 65 and Over',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  'Total Population: White Alone',
# ...

# %%
#drop columns
edemog2012.drop(columns=['Qualifying Name','Summary Level',
 'Geographic Component',
 'File Identification',
 'Logical Record Number',
 'State (FIPS)',
 'County',
 'Geographic Identifier',
 'Area (Land)',
 'Area (Water)','Area Total: Area (Land)',
 'Area Total: Area (Water)','Total Population: Male',
 'Total Population: Female','Total Population: Under 18 Years',
 'Total Population: 18 to 34 Years',
 'Total Population: 35 to 64 Years',
 'Total Population: 65 and Over','Total Population: White Alone',
 'Total Population: Black or African American Alone',
 'Total Population: American Indian and Alaska Native Alone',
 'Total Population: Asian Alone',
 'Total Population: Native Hawaiian and Other Pacific Islander Alone',
 'Total Population: Some Other Race Alone',
 'Total Population: Two or More Races','Population 15 Years and Over:',
 'Population 15 Years and Over: Never Married',
 'Population 15 Years and Over: Now Married (Not Including Separated)',
 'Population 15 Years and Over: Separated',
 'Population 15 Years and Over: Widowed',
 'Population 15 Years and Over: Divorced','Households: Family Households',
 'Households: Family Households: Married-Couple Family',
 'Households: Family Households: Other Family',
 'Households: Family Households: Other Family: Male Householder, No Wife Present',
 'Households: Family Households: Other Family: Female Householder, No Husband Present',
 'Households: Nonfamily Households',
 'Households: Nonfamily Households: Male Householder',
 'Households: Nonfamily Households: Female Householder','Occupied Housing Units: 1-Person Household',
 'Occupied Housing Units: 2-Person Household',
 'Occupied Housing Units: 3-Person Household',
 'Occupied Housing Units: 4-Person Household',
 'Occupied Housing Units: 5-Person Household',
 'Occupied Housing Units: 6-Person Household',
 'Occupied Housing Units: 7-or-More Person Household','Households: Unmarried-Partner Households',
 'Households: Unmarried-Partner Households: Same Sex Partners',
 'Households: Unmarried-Partner Households: Same Sex Partners: Male Householder and Male Partner',
 'Households: Unmarried-Partner Households: Same Sex Partners: Female Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Male Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Female Householder and Male Partner',
 'Households: All Other Households','Occupied Housing Units.1','Civilian Population 18 Years and Over: Veteran',
 'Civilian Population 18 Years and Over: Veteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Veteran: 65 Years and Over',
 'Civilian Population 18 Years and Over: Nonveteran',
 'Civilian Population 18 Years and Over: Nonveteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Nonveteran: 65 Years and Over','Civilian Veterans 18 Years and Over:',
 'Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 'Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 'Civilian Veterans 18 Years and Over: Vietnam Era Only',
 'Civilian Veterans 18 Years and Over: Korean War Only',
 'Civilian Veterans 18 Years and Over: World War Ii Only',
 'Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 'Civilian Veterans 18 Years and Over: Other Service',
 '% Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 '% Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 '% Civilian Veterans 18 Years and Over: Vietnam Era Only',
 '% Civilian Veterans 18 Years and Over: Korean War Only',
 '% Civilian Veterans 18 Years and Over: World War Ii Only',
 '% Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 '% Civilian Veterans 18 Years and Over: Other Service'], inplace = True)

# %%
#Rename column
edemog2012.rename(columns={'Year':'year'}, inplace = True)

# %%
edemog2012.head()
# Out:
#    year  FIPS             Name of Area State/U.S.-Abbreviation (USPS)  \
# 0  2012  1003  Baldwin County, Alabama                             al
# 1  2012  1015  Calhoun County, Alabama                             al
# 2  2012  1043  Cullman County, Alabama                             al
# 3  2012  1049   DeKalb County, Alabama                             al
# 4  2012  1051   Elmore County, Alabama                             al
#
#    Area Total:  % Area Total: Area (Land)  % Area Total: Area (Water)  \
# 0    2027.3120                      78.42                       21.58
# 1     612.2864                      98.95                        1.05
# 2     755.0209                      97.33                        2.67
# 3     778.6854                      99.80                        0.20
# 4     657.0417                      94.13                        5.87
#
#    Total Population  Population Density (Per Sq. Mile)  \
# 0            190790                         120.005786
# ...

# %%
list(ACS2012.columns.values)
# Out:
# ['year',
#  'FIPS',
#  'Name of Area',
#  'Qualifying Name',
#  'State/U.S.-Abbreviation (USPS)',
#  'Summary Level',
#  'Geographic Component',
#  'File Identification',
#  'Logical Record Number',
#  'State (FIPS)',
#  'County',
#  'Geographic Identifier',
#  'Area (Land)',
#  'Area (Water)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Area Total:',
#  'Area Total: Area (Land)',
#  'Area Total: Area (Water)',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  'Total Population: Male',
#  'Total Population: Female',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  'Total Population: Under 18 Years',
#  'Total Population: 18 to 34 Years',
#  'Total Population: 35 to 64 Years',
#  'Total Population: 65 and Over',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  'Total Population: White Alone',
# ...

# %%
#drop columns
ACS2012.drop(columns=['Qualifying Name','Summary Level',
 'Geographic Component',
 'File Identification',
 'Logical Record Number',
 'State (FIPS)',
 'County',
 'Geographic Identifier',
 'Area (Land)',
 'Area (Water)','Area Total: Area (Land)',
 'Area Total: Area (Water)','Total Population: Male',
 'Total Population: Female','Total Population: Under 18 Years',
 'Total Population: 18 to 34 Years',
 'Total Population: 35 to 64 Years',
 'Total Population: 65 and Over','Total Population: White Alone',
 'Total Population: Black or African American Alone',
 'Total Population: American Indian and Alaska Native Alone',
 'Total Population: Asian Alone',
 'Total Population: Native Hawaiian and Other Pacific Islander Alone',
 'Total Population: Some Other Race Alone',
 'Total Population: Two or More Races','Households: Family Households',
 'Households: Family Households: Married-Couple Family',
 'Households: Family Households: Other Family',
 'Households: Family Households: Other Family: Male Householder, No Wife Present',
 'Households: Family Households: Other Family: Female Householder, No Husband Present',
 'Households: Nonfamily Households',
 'Households: Nonfamily Households: Male Householder',
 'Households: Nonfamily Households: Female Householder','Occupied Housing Units: 1-Person Household',
 'Occupied Housing Units: 2-Person Household',
 'Occupied Housing Units: 3-Person Household',
 'Occupied Housing Units: 4-Person Household',
 'Occupied Housing Units: 5-Person Household',
 'Occupied Housing Units: 6-Person Household',
 'Occupied Housing Units: 7-or-More Person Household','Population 15 Years and Over:',
 'Population 15 Years and Over: Never Married',
 'Population 15 Years and Over: Now Married (Not Including Separated)',
 'Population 15 Years and Over: Separated',
 'Population 15 Years and Over: Widowed',
 'Population 15 Years and Over: Divorced','Households: Unmarried-Partner Households',
 'Households: Unmarried-Partner Households: Same Sex Partners',
 'Households: Unmarried-Partner Households: Same Sex Partners: Male Householder and Male Partner',
 'Households: Unmarried-Partner Households: Same Sex Partners: Female Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Male Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Female Householder and Male Partner',
 'Households: All Other Households','Population 25 Years and Over:',
 'Population 25 Years and Over: Less than High School',
 'Population 25 Years and Over: High School Graduate (Includes Equivalency)',
 'Population 25 Years and Over: Some College',
 "Population 25 Years and Over: Bachelor's Degree",
 "Population 25 Years and Over: Master's Degree",
 'Population 25 Years and Over: Professional School Degree',
 'Population 25 Years and Over: Doctorate Degree',
 '% Population 25 Years and Over: Less than High School',
 '% Population 25 Years and Over: High School Graduate (Includes Equivalency)',
 '% Population 25 Years and Over: Some College',
 "% Population 25 Years and Over: Bachelor's Degree",
 "% Population 25 Years and Over: Master's Degree",
 '% Population 25 Years and Over: Professional School Degree',
 '% Population 25 Years and Over: Doctorate Degree',
 'Occupied Housing Units.1',
 'Occupied Housing Units: Less than High School Graduate',
 'Occupied Housing Units: High School Graduate (Including Equivalency)',
 "Occupied Housing Units: Some College or Associate's Degree",
 "Occupied Housing Units: Bachelor's Degree or Higher",'Civilian Population 18 Years and Over:','% Occupied Housing Units: Less than High School Graduate',
 '% Occupied Housing Units: High School Graduate (Including Equivalency)',
 "% Occupied Housing Units: Some College or Associate's Degree",
 "% Occupied Housing Units: Bachelor's Degree or Higher",
 'Civilian Population 18 Years and Over: Veteran',
 'Civilian Population 18 Years and Over: Veteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Veteran: 65 Years and Over',
 'Civilian Population 18 Years and Over: Nonveteran',
 'Civilian Population 18 Years and Over: Nonveteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Nonveteran: 65 Years and Over','Civilian Veterans 18 Years and Over:',
 'Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 'Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 'Civilian Veterans 18 Years and Over: Vietnam Era Only',
 'Civilian Veterans 18 Years and Over: Korean War Only',
 'Civilian Veterans 18 Years and Over: World War Ii Only',
 'Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 'Civilian Veterans 18 Years and Over: Other Service',
 '% Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 '% Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 '% Civilian Veterans 18 Years and Over: Vietnam Era Only',
 '% Civilian Veterans 18 Years and Over: Korean War Only',
 '% Civilian Veterans 18 Years and Over: World War Ii Only',
 '% Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 '% Civilian Veterans 18 Years and Over: Other Service'], inplace=True)

# %%
ACS2012
# Out:
#       year   FIPS                      Name of Area  \
# 0     2012   1001           Autauga County, Alabama
# 1     2012   1003           Baldwin County, Alabama
# 2     2012   1005           Barbour County, Alabama
# 3     2012   1007              Bibb County, Alabama
# 4     2012   1009            Blount County, Alabama
# ...    ...    ...                               ...
# 3216  2012  72145  Vega Baja Municipio, Puerto Rico
# 3217  2012  72147    Vieques Municipio, Puerto Rico
# 3218  2012  72149   Villalba Municipio, Puerto Rico
# 3219  2012  72151    Yabucoa Municipio, Puerto Rico
# 3220  2012  72153      Yauco Municipio, Puerto Rico
#
#      State/U.S.-Abbreviation (USPS)  Total Population  \
# 0                                al             54590
# 1                                al            183226
# 2                                al             27469
# 3                                al             22769
# 4                                al             57466
# ...

# %%
#filling missing counties using 5yr file
missing2012=ACS2012[~ACS2012.FIPS.isin(edemog2012.FIPS)]
list(missing2012.columns.values)
# Out:
# ['year',
#  'FIPS',
#  'Name of Area',
#  'State/U.S.-Abbreviation (USPS)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Area Total:',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  '% Total Population: White Alone',
#  '% Total Population: Black or African American Alone',
#  '% Total Population: American Indian and Alaska Native Alone',
#  '% Total Population: Asian Alone',
#  '% Total Population: Native Hawaiian and Other Pacific Islander Alone',
#  '% Total Population: Some Other Race Alone',
#  '% Total Population: Two or More Races',
#  'Households:',
#  '% Households: Family Households',
#  '% Households: Family Households: Married-Couple Family',
#  '% Households: Family Households: Other Family',
# ...

# %%
missing2012
# Out:
#       year   FIPS                      Name of Area  \
# 0     2012   1001           Autauga County, Alabama
# 2     2012   1005           Barbour County, Alabama
# 3     2012   1007              Bibb County, Alabama
# 4     2012   1009            Blount County, Alabama
# 5     2012   1011           Bullock County, Alabama
# ...    ...    ...                               ...
# 3216  2012  72145  Vega Baja Municipio, Puerto Rico
# 3217  2012  72147    Vieques Municipio, Puerto Rico
# 3218  2012  72149   Villalba Municipio, Puerto Rico
# 3219  2012  72151    Yabucoa Municipio, Puerto Rico
# 3220  2012  72153      Yauco Municipio, Puerto Rico
#
#      State/U.S.-Abbreviation (USPS)  Total Population  \
# 0                                al             54590
# 2                                al             27469
# 3                                al             22769
# 4                                al             57466
# 5                                al             10779
# ...

# %%
#append missing 2012 with cleaned demog2012
edemog2012_final=pd.concat([edemog2012,missing2012], sort=False)
edemog2012_final.sort_values(by=['FIPS'])
#reset index
edemog2012_final=edemog2012_final.reset_index(drop=True)

edemog2012_final
# Out:
#       year   FIPS                      Name of Area  \
# 0     2012   1003           Baldwin County, Alabama
# 1     2012   1015           Calhoun County, Alabama
# 2     2012   1043           Cullman County, Alabama
# 3     2012   1049            DeKalb County, Alabama
# 4     2012   1051            Elmore County, Alabama
# ...    ...    ...                               ...
# 3216  2012  72145  Vega Baja Municipio, Puerto Rico
# 3217  2012  72147    Vieques Municipio, Puerto Rico
# 3218  2012  72149   Villalba Municipio, Puerto Rico
# 3219  2012  72151    Yabucoa Municipio, Puerto Rico
# 3220  2012  72153      Yauco Municipio, Puerto Rico
#
#      State/U.S.-Abbreviation (USPS)  Area Total:  % Area Total: Area (Land)  \
# 0                                al   2027.31200                      78.42
# 1                                al    612.28640                      98.95
# 2                                al    755.02090                      97.33
# ...

# %% [markdown]
# # 2016

# %%
edemog2016.head()
# Out:
#    Year  FIPS             Name of Area          Qualifying Name  \
# 0  2016  1003  Baldwin County, Alabama  Baldwin County, Alabama
# 1  2016  1015  Calhoun County, Alabama  Calhoun County, Alabama
# 2  2016  1043  Cullman County, Alabama  Cullman County, Alabama
# 3  2016  1049   DeKalb County, Alabama   DeKalb County, Alabama
# 4  2016  1051   Elmore County, Alabama   Elmore County, Alabama
#
#   State/U.S.-Abbreviation (USPS)  Summary Level  Geographic Component  \
# 0                             al             50                     0
# 1                             al             50                     0
# 2                             al             50                     0
# 3                             al             50                     0
# 4                             al             50                     0
#
#   File Identification  Logical Record Number  State (FIPS)  ...  \
# 0               ACSSF                     13             1  ...
# ...

# %%
list(edemog2016.columns.values)
# Out:
# ['Year',
#  'FIPS',
#  'Name of Area',
#  'Qualifying Name',
#  'State/U.S.-Abbreviation (USPS)',
#  'Summary Level',
#  'Geographic Component',
#  'File Identification',
#  'Logical Record Number',
#  'State (FIPS)',
#  'County',
#  'Geographic Identifier',
#  'Area (Land)',
#  'Area (Water)',
#  'Area Total:',
#  'Area Total: Area (Land)',
#  'Area Total: Area (Water)',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Total Population: Male',
#  'Total Population: Female',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  'Total Population: Under 18 Years',
#  'Total Population: 18 to 34 Years',
#  'Total Population: 35 to 64 Years',
#  'Total Population: 65 and Over',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  'Total Population: White Alone',
# ...

# %%
#drop columns
edemog2016.drop(columns=['Qualifying Name','Summary Level',
 'Geographic Component',
 'File Identification',
 'Logical Record Number',
 'State (FIPS)',
 'County',
 'Geographic Identifier',
 'Area (Land)',
 'Area (Water)','Area Total: Area (Land)',
 'Area Total: Area (Water)','Total Population: Male',
 'Total Population: Female','Total Population: Under 18 Years',
 'Total Population: 18 to 34 Years',
 'Total Population: 35 to 64 Years',
 'Total Population: 65 and Over','Total Population: White Alone',
 'Total Population: Black or African American Alone',
 'Total Population: American Indian and Alaska Native Alone',
 'Total Population: Asian Alone',
 'Total Population: Native Hawaiian and Other Pacific Islander Alone',
 'Total Population: Some Other Race Alone',
 'Total Population: Two or More Races','Population 15 Years and Over:',
 'Population 15 Years and Over: Never Married',
 'Population 15 Years and Over: Now Married (Not Including Separated)',
 'Population 15 Years and Over: Separated',
 'Population 15 Years and Over: Widowed',
 'Population 15 Years and Over: Divorced','Households: Family Households',
 'Households: Family Households: Married-Couple Family',
 'Households: Family Households: Other Family',
 'Households: Family Households: Other Family: Male Householder, No Wife Present',
 'Households: Family Households: Other Family: Female Householder, No Husband Present',
 'Households: Nonfamily Households',
 'Households: Nonfamily Households: Male Householder',
 'Households: Nonfamily Households: Female Householder','Occupied Housing Units: 1-Person Household',
 'Occupied Housing Units: 2-Person Household',
 'Occupied Housing Units: 3-Person Household',
 'Occupied Housing Units: 4-Person Household',
 'Occupied Housing Units: 5-Person Household',
 'Occupied Housing Units: 6-Person Household',
 'Occupied Housing Units: 7-or-More Person Household','Households: Unmarried-Partner Households',
 'Households: Unmarried-Partner Households: Same Sex Partners',
 'Households: Unmarried-Partner Households: Same Sex Partners: Male Householder and Male Partner',
 'Households: Unmarried-Partner Households: Same Sex Partners: Female Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Male Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Female Householder and Male Partner',
 'Households: All Other Households','Occupied Housing Units.1','Civilian Population 18 Years and Over: Veteran',
 'Civilian Population 18 Years and Over: Veteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Veteran: 65 Years and Over',
 'Civilian Population 18 Years and Over: Nonveteran',
 'Civilian Population 18 Years and Over: Nonveteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Nonveteran: 65 Years and Over','Civilian Veterans 18 Years and Over:',
 'Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 'Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 'Civilian Veterans 18 Years and Over: Vietnam Era Only',
 'Civilian Veterans 18 Years and Over: Korean War Only',
 'Civilian Veterans 18 Years and Over: World War Ii Only',
 'Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 'Civilian Veterans 18 Years and Over: Other Service',
 '% Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 '% Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 '% Civilian Veterans 18 Years and Over: Vietnam Era Only',
 '% Civilian Veterans 18 Years and Over: Korean War Only',
 '% Civilian Veterans 18 Years and Over: World War Ii Only',
 '% Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 '% Civilian Veterans 18 Years and Over: Other Service'], inplace = True)

# %%
#Rename column
edemog2016.rename(columns={'Year':'year'}, inplace = True)

# %%
edemog2016.head()
# Out:
#    year  FIPS             Name of Area State/U.S.-Abbreviation (USPS)  \
# 0  2016  1003  Baldwin County, Alabama                             al
# 1  2016  1015  Calhoun County, Alabama                             al
# 2  2016  1043  Cullman County, Alabama                             al
# 3  2016  1049   DeKalb County, Alabama                             al
# 4  2016  1051   Elmore County, Alabama                             al
#
#    Area Total:  % Area Total: Area (Land)  % Area Total: Area (Water)  \
# 0    2027.3120                      78.42                       21.58
# 1     612.2863                      98.96                        1.04
# 2     755.0211                      97.33                        2.67
# 3     778.6854                      99.80                        0.20
# 4     657.0406                      94.13                        5.87
#
#    Total Population  Population Density (Per Sq. Mile)  \
# 0            208563                         131.187524
# ...

# %%
list(ACS2016.columns.values)
# Out:
# ['year',
#  'FIPS',
#  'Name of Area',
#  'Qualifying Name',
#  'State/U.S.-Abbreviation (USPS)',
#  'Summary Level',
#  'Geographic Component',
#  'File Identification',
#  'Logical Record Number',
#  'State (FIPS)',
#  'County',
#  'Geographic Identifier',
#  'Area (Land)',
#  'Area (Water)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Area Total:',
#  'Area Total: Area (Land)',
#  'Area Total: Area (Water)',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  'Total Population: Male',
#  'Total Population: Female',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  'Total Population: Under 18 Years',
#  'Total Population: 18 to 34 Years',
#  'Total Population: 35 to 64 Years',
#  'Total Population: 65 and Over',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  'Total Population: White Alone',
# ...

# %%
#drop columns
ACS2016.drop(columns=['Qualifying Name','Summary Level',
 'Geographic Component',
 'File Identification',
 'Logical Record Number',
 'State (FIPS)',
 'County',
 'Geographic Identifier',
 'Area (Land)',
 'Area (Water)','Area Total: Area (Land)',
 'Area Total: Area (Water)','Total Population: Male',
 'Total Population: Female','Total Population: Under 18 Years',
 'Total Population: 18 to 34 Years',
 'Total Population: 35 to 64 Years',
 'Total Population: 65 and Over','Total Population: White Alone',
 'Total Population: Black or African American Alone',
 'Total Population: American Indian and Alaska Native Alone',
 'Total Population: Asian Alone',
 'Total Population: Native Hawaiian and Other Pacific Islander Alone',
 'Total Population: Some Other Race Alone',
 'Total Population: Two or More Races','Households: Family Households',
 'Households: Family Households: Married-Couple Family',
 'Households: Family Households: Other Family',
 'Households: Family Households: Other Family: Male Householder, No Wife Present',
 'Households: Family Households: Other Family: Female Householder, No Husband Present',
 'Households: Nonfamily Households',
 'Households: Nonfamily Households: Male Householder',
 'Households: Nonfamily Households: Female Householder','Occupied Housing Units: 1-Person Household',
 'Occupied Housing Units: 2-Person Household',
 'Occupied Housing Units: 3-Person Household',
 'Occupied Housing Units: 4-Person Household',
 'Occupied Housing Units: 5-Person Household',
 'Occupied Housing Units: 6-Person Household',
 'Occupied Housing Units: 7-or-More Person Household','Population 15 Years and Over:',
 'Population 15 Years and Over: Never Married',
 'Population 15 Years and Over: Now Married (Not Including Separated)',
 'Population 15 Years and Over: Separated',
 'Population 15 Years and Over: Widowed',
 'Population 15 Years and Over: Divorced','Households: Unmarried-Partner Households',
 'Households: Unmarried-Partner Households: Same Sex Partners',
 'Households: Unmarried-Partner Households: Same Sex Partners: Male Householder and Male Partner',
 'Households: Unmarried-Partner Households: Same Sex Partners: Female Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Male Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Female Householder and Male Partner',
 'Households: All Other Households','Population 25 Years and Over:',
 'Population 25 Years and Over: Less than High School',
 'Population 25 Years and Over: High School Graduate (Includes Equivalency)',
 'Population 25 Years and Over: Some College',
 "Population 25 Years and Over: Bachelor's Degree",
 "Population 25 Years and Over: Master's Degree",
 'Population 25 Years and Over: Professional School Degree',
 'Population 25 Years and Over: Doctorate Degree',
 '% Population 25 Years and Over: Less than High School',
 '% Population 25 Years and Over: High School Graduate (Includes Equivalency)',
 '% Population 25 Years and Over: Some College',
 "% Population 25 Years and Over: Bachelor's Degree",
 "% Population 25 Years and Over: Master's Degree",
 '% Population 25 Years and Over: Professional School Degree',
 '% Population 25 Years and Over: Doctorate Degree',
 'Occupied Housing Units.1',
 'Occupied Housing Units: Less than High School Graduate',
 'Occupied Housing Units: High School Graduate (Including Equivalency)',
 "Occupied Housing Units: Some College or Associate's Degree",
 "Occupied Housing Units: Bachelor's Degree or Higher",'Civilian Population 18 Years and Over:','% Occupied Housing Units: Less than High School Graduate',
 '% Occupied Housing Units: High School Graduate (Including Equivalency)',
 "% Occupied Housing Units: Some College or Associate's Degree",
 "% Occupied Housing Units: Bachelor's Degree or Higher",
 'Civilian Population 18 Years and Over: Veteran',
 'Civilian Population 18 Years and Over: Veteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Veteran: 65 Years and Over',
 'Civilian Population 18 Years and Over: Nonveteran',
 'Civilian Population 18 Years and Over: Nonveteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Nonveteran: 65 Years and Over','Civilian Veterans 18 Years and Over:',
 'Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 'Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 'Civilian Veterans 18 Years and Over: Vietnam Era Only',
 'Civilian Veterans 18 Years and Over: Korean War Only',
 'Civilian Veterans 18 Years and Over: World War Ii Only',
 'Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 'Civilian Veterans 18 Years and Over: Other Service',
 '% Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 '% Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 '% Civilian Veterans 18 Years and Over: Vietnam Era Only',
 '% Civilian Veterans 18 Years and Over: Korean War Only',
 '% Civilian Veterans 18 Years and Over: World War Ii Only',
 '% Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 '% Civilian Veterans 18 Years and Over: Other Service'], inplace=True)

# %%
ACS2016
# Out:
#       year   FIPS                      Name of Area  \
# 0     2016   1001           Autauga County, Alabama
# 1     2016   1003           Baldwin County, Alabama
# 2     2016   1005           Barbour County, Alabama
# 3     2016   1007              Bibb County, Alabama
# 4     2016   1009            Blount County, Alabama
# ...    ...    ...                               ...
# 3215  2016  72145  Vega Baja Municipio, Puerto Rico
# 3216  2016  72147    Vieques Municipio, Puerto Rico
# 3217  2016  72149   Villalba Municipio, Puerto Rico
# 3218  2016  72151    Yabucoa Municipio, Puerto Rico
# 3219  2016  72153      Yauco Municipio, Puerto Rico
#
#      State/U.S.-Abbreviation (USPS)  Total Population  \
# 0                                al             55049
# 1                                al            199510
# 2                                al             26614
# 3                                al             22572
# 4                                al             57704
# ...

# %%
#filling missing counties using 5yr file
missing2016=ACS2016[~ACS2016.FIPS.isin(edemog2016.FIPS)]
list(missing2016.columns.values)
# Out:
# ['year',
#  'FIPS',
#  'Name of Area',
#  'State/U.S.-Abbreviation (USPS)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Area Total:',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  '% Total Population: White Alone',
#  '% Total Population: Black or African American Alone',
#  '% Total Population: American Indian and Alaska Native Alone',
#  '% Total Population: Asian Alone',
#  '% Total Population: Native Hawaiian and Other Pacific Islander Alone',
#  '% Total Population: Some Other Race Alone',
#  '% Total Population: Two or More Races',
#  'Households:',
#  '% Households: Family Households',
#  '% Households: Family Households: Married-Couple Family',
#  '% Households: Family Households: Other Family',
# ...

# %%
missing2016
# Out:
#       year   FIPS                      Name of Area  \
# 0     2016   1001           Autauga County, Alabama
# 2     2016   1005           Barbour County, Alabama
# 3     2016   1007              Bibb County, Alabama
# 4     2016   1009            Blount County, Alabama
# 5     2016   1011           Bullock County, Alabama
# ...    ...    ...                               ...
# 3215  2016  72145  Vega Baja Municipio, Puerto Rico
# 3216  2016  72147    Vieques Municipio, Puerto Rico
# 3217  2016  72149   Villalba Municipio, Puerto Rico
# 3218  2016  72151    Yabucoa Municipio, Puerto Rico
# 3219  2016  72153      Yauco Municipio, Puerto Rico
#
#      State/U.S.-Abbreviation (USPS)  Total Population  \
# 0                                al             55049
# 2                                al             26614
# 3                                al             22572
# 4                                al             57704
# 5                                al             10552
# ...

# %%
#append missing 2016 with cleaned demog2016
edemog2016_final=pd.concat([edemog2016,missing2016], sort=False)
edemog2016_final.sort_values(by=['FIPS'])
#reset index
edemog2016_final=edemog2016_final.reset_index(drop=True)

edemog2016_final
# Out:
#       year   FIPS                      Name of Area  \
# 0     2016   1003           Baldwin County, Alabama
# 1     2016   1015           Calhoun County, Alabama
# 2     2016   1043           Cullman County, Alabama
# 3     2016   1049            DeKalb County, Alabama
# 4     2016   1051            Elmore County, Alabama
# ...    ...    ...                               ...
# 3215  2016  72145  Vega Baja Municipio, Puerto Rico
# 3216  2016  72147    Vieques Municipio, Puerto Rico
# 3217  2016  72149   Villalba Municipio, Puerto Rico
# 3218  2016  72151    Yabucoa Municipio, Puerto Rico
# 3219  2016  72153      Yauco Municipio, Puerto Rico
#
#      State/U.S.-Abbreviation (USPS)  Area Total:  % Area Total: Area (Land)  \
# 0                                al   2027.31200                      78.42
# 1                                al    612.28630                      98.96
# 2                                al    755.02110                      97.33
# ...

# %% [markdown]
# # 2020

# %%
edemog2020.head()
# Out:
#    Year  FIPS    Name of Area          Qualifying Name  \
# 0  2018  1001  Autauga County  Autauga County, Alabama
# 1  2018  1003  Baldwin County  Baldwin County, Alabama
# 2  2018  1005  Barbour County  Barbour County, Alabama
# 3  2018  1007     Bibb County     Bibb County, Alabama
# 4  2018  1009   Blount County   Blount County, Alabama
#
#   State/U.S.-Abbreviation (USPS)  Summary Level  Geographic Component  \
# 0                             al             50                     0
# 1                             al             50                     0
# 2                             al             50                     0
# 3                             al             50                     0
# 4                             al             50                     0
#
#   File Identification  Logical Record Number  State (FIPS)  ...  \
# 0               ACSSF                     13             1  ...
# 1               ACSSF                     14             1  ...
# ...

# %%
list(edemog2020.columns.values)
# Out:
# ['Year',
#  'FIPS',
#  'Name of Area',
#  'Qualifying Name',
#  'State/U.S.-Abbreviation (USPS)',
#  'Summary Level',
#  'Geographic Component',
#  'File Identification',
#  'Logical Record Number',
#  'State (FIPS)',
#  'County',
#  'Geographic Identifier',
#  'Area (Land)',
#  'Area (Water)',
#  'Area Total:',
#  'Area Total: Area (Land)',
#  'Area Total: Area (Water)',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Total Population: Male',
#  'Total Population: Female',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  'Total Population: Under 18 Years',
#  'Total Population: 18 to 34 Years',
#  'Total Population: 35 to 64 Years',
#  'Total Population: 65 and Over',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  'Total Population: White Alone',
# ...

# %%
#drop columns
edemog2020.drop(columns=['Qualifying Name','Summary Level',
 'Geographic Component',
 'File Identification',
 'Logical Record Number',
 'State (FIPS)',
 'County',
 'Geographic Identifier',
 'Area (Land)',
 'Area (Water)','Area Total: Area (Land)',
 'Area Total: Area (Water)','Total Population: Male',
 'Total Population: Female','Total Population: Under 18 Years',
 'Total Population: 18 to 34 Years',
 'Total Population: 35 to 64 Years',
 'Total Population: 65 and Over','Total Population: White Alone',
 'Total Population: Black or African American Alone',
 'Total Population: American Indian and Alaska Native Alone',
 'Total Population: Asian Alone',
 'Total Population: Native Hawaiian and Other Pacific Islander Alone',
 'Total Population: Some Other Race Alone',
 'Total Population: Two or More Races','Population 15 Years and Over:',
 'Population 15 Years and Over: Never Married',
 'Population 15 Years and Over: Now Married (Not Including Separated)',
 'Population 15 Years and Over: Separated',
 'Population 15 Years and Over: Widowed',
 'Population 15 Years and Over: Divorced','Households: Family Households',
 'Households: Family Households: Married-Couple Family',
 'Households: Family Households: Other Family',
 'Households: Family Households: Other Family: Male Householder, No Wife Present',
 'Households: Family Households: Other Family: Female Householder, No Husband Present',
 'Households: Nonfamily Households',
 'Households: Nonfamily Households: Male Householder',
 'Households: Nonfamily Households: Female Householder','Occupied Housing Units: 1-Person Household',
 'Occupied Housing Units: 2-Person Household',
 'Occupied Housing Units: 3-Person Household',
 'Occupied Housing Units: 4-Person Household',
 'Occupied Housing Units: 5-Person Household',
 'Occupied Housing Units: 6-Person Household',
 'Occupied Housing Units: 7-or-More Person Household','Households: Unmarried-Partner Households',
 'Households: Unmarried-Partner Households: Same Sex Partners',
 'Households: Unmarried-Partner Households: Same Sex Partners: Male Householder and Male Partner',
 'Households: Unmarried-Partner Households: Same Sex Partners: Female Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Male Householder and Female Partner',
 'Households: Unmarried-Partner Households: Opposite Sex Partners: Female Householder and Male Partner',
 'Households: All Other Households','Occupied Housing Units.1','Civilian Population 18 Years and Over: Veteran',
 'Civilian Population 18 Years and Over: Veteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Veteran: 65 Years and Over',
 'Civilian Population 18 Years and Over: Nonveteran',
 'Civilian Population 18 Years and Over: Nonveteran: 18 to 64 Years',
 'Civilian Population 18 Years and Over: Nonveteran: 65 Years and Over','Civilian Veterans 18 Years and Over:',
 'Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 'Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 'Civilian Veterans 18 Years and Over: Vietnam Era Only',
 'Civilian Veterans 18 Years and Over: Korean War Only',
 'Civilian Veterans 18 Years and Over: World War Ii Only',
 'Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 'Civilian Veterans 18 Years and Over: Other Service',
 '% Civilian Veterans 18 Years and Over: Gulf War 2001 or Later Only',
 '% Civilian Veterans 18 Years and Over: Gulf War 1990 to 2001 Only',
 '% Civilian Veterans 18 Years and Over: Vietnam Era Only',
 '% Civilian Veterans 18 Years and Over: Korean War Only',
 '% Civilian Veterans 18 Years and Over: World War Ii Only',
 '% Civilian Veterans 18 Years and Over: Served in Multiple Wars',
 '% Civilian Veterans 18 Years and Over: Other Service'], inplace = True)

# %%
#Rename column
edemog2020.rename(columns={'Year':'year'}, inplace = True)

# %%
edemog2020
# Out:
#       year   FIPS         Name of Area State/U.S.-Abbreviation (USPS)  \
# 0     2018   1001       Autauga County                             al
# 1     2018   1003       Baldwin County                             al
# 2     2018   1005       Barbour County                             al
# 3     2018   1007          Bibb County                             al
# 4     2018   1009        Blount County                             al
# ...    ...    ...                  ...                            ...
# 3215  2018  72145  Vega Baja Municipio                             pr
# 3216  2018  72147    Vieques Municipio                             pr
# 3217  2018  72149   Villalba Municipio                             pr
# 3218  2018  72151    Yabucoa Municipio                             pr
# 3219  2018  72153      Yauco Municipio                             pr
#
#       Area Total:  % Area Total: Area (Land)  % Area Total: Area (Water)  \
# ...

# %%
# making finished file a csv
path = 'Demographics/Elec2020Demographics_cleaned_wNaN.csv'
edemog2020.to_csv(path,index=False)

# %% [markdown]
# # Merge with Election Data

# %%
merged2008=pd.merge(Election2008,edemog2008_final,how='left', on=['year', 'FIPS'])

# %%
# YearDrop2012 = merged2008[merged2008['year']=='2012'].index
# YearDrop2016 = merged2008[merged2008['year']=='2016'].index
# # Delete these row indexes from dataFrame
# merged2008.drop(YearDrop2012, inplace=True)
merged2008
# Out:
#       FIPS    state       county  year   FIPS/Year  totalvotes  \
# 0     1001  Alabama      Autauga  2008  2008/01001       23641
# 1     1003  Alabama      Baldwin  2008  2008/01003       81413
# 2     1005  Alabama      Barbour  2008  2008/01005       11630
# 3     1007  Alabama         Bibb  2008  2008/01007        8644
# 4     1009  Alabama       Blount  2008  2008/01009       24267
# ...    ...      ...          ...   ...         ...         ...
# 3150  2037   Alaska  District 37  2008  2008/02037        4665
# 3151  2038   Alaska  District 38  2008  2008/02038        4820
# 3152  2039   Alaska  District 39  2008  2008/02039        5184
# 3153  2040   Alaska  District 40  2008  2008/02040        5000
# 3154  2099   Alaska  District 99  2008  2008/02099           0
#
#       dem_vote_share  rep_vote_share  other_vote_share winning_party  ...  \
# 0           0.257730        0.736136          0.006133    Republican  ...
# ...

# %%
merged2012=pd.merge(Election2012,edemog2012_final,how='left', on=['year', 'FIPS'])
merged2012
# Out:
#       FIPS    state       county  year   FIPS/Year  totalvotes  \
# 0     1001  Alabama      Autauga  2012  2012/01001       23932
# 1     1003  Alabama      Baldwin  2012  2012/01003       85338
# 2     1005  Alabama      Barbour  2012  2012/01005       11509
# 3     1007  Alabama         Bibb  2012  2012/01007        8420
# 4     1009  Alabama       Blount  2012  2012/01009       24006
# ...    ...      ...          ...   ...         ...         ...
# 3150  2037   Alaska  District 37  2012  2012/02037        4335
# 3151  2038   Alaska  District 38  2012  2012/02038        6814
# 3152  2039   Alaska  District 39  2012  2012/02039        6560
# 3153  2040   Alaska  District 40  2012  2012/02040        4235
# 3154  2099   Alaska  District 99  2012  2012/02099       74045
#
#       dem_vote_share  rep_vote_share  other_vote_share winning_party  ...  \
# 0           0.265878        0.726183          0.007939    Republican  ...
# ...

# %%
merged2016=pd.merge(Election2016,edemog2016_final,how='left', on=['year', 'FIPS'])
merged2016
# Out:
#       FIPS    state       county  year   FIPS/Year  totalvotes  \
# 0     1001  Alabama      Autauga  2016  2016/01001       24973
# 1     1003  Alabama      Baldwin  2016  2016/01003       95215
# 2     1005  Alabama      Barbour  2016  2016/01005       10469
# 3     1007  Alabama         Bibb  2016  2016/01007        8819
# 4     1009  Alabama       Blount  2016  2016/01009       25588
# ...    ...      ...          ...   ...         ...         ...
# 3150  2037   Alaska  District 37  2016  2016/02037        5062
# 3151  2038   Alaska  District 38  2016  2016/02038        5095
# 3152  2039   Alaska  District 39  2016  2016/02039        5639
# 3153  2040   Alaska  District 40  2016  2016/02040        4610
# 3154  2099   Alaska  District 99  2016  2016/02099        5056
#
#       dem_vote_share  rep_vote_share  other_vote_share winning_party  ...  \
# 0           0.237697        0.727666          0.034637    Republican  ...
# ...

# %%
list(merged2016.columns.values)
# Out:
# ['FIPS',
#  'state',
#  'county',
#  'year',
#  'FIPS/Year',
#  'totalvotes',
#  'dem_vote_share',
#  'rep_vote_share',
#  'other_vote_share',
#  'winning_party',
#  'republican_minus_democratic',
#  'Name of Area',
#  'State/U.S.-Abbreviation (USPS)',
#  'Area Total:',
#  '% Area Total: Area (Land)',
#  '% Area Total: Area (Water)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  '% Total Population: Male',
#  '% Total Population: Female',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  '% Total Population: White Alone',
#  '% Total Population: Black or African American Alone',
#  '% Total Population: American Indian and Alaska Native Alone',
#  '% Total Population: Asian Alone',
#  '% Total Population: Native Hawaiian and Other Pacific Islander Alone',
#  '% Total Population: Some Other Race Alone',
#  '% Total Population: Two or More Races',
# ...

# %%
ElectionDemogMerged=pd.concat([merged2008,merged2012,merged2016])
ElectionDemogMerged
#9465 rows of county data
# Out:
#       FIPS    state       county  year   FIPS/Year  totalvotes  \
# 0     1001  Alabama      Autauga  2008  2008/01001       23641
# 1     1003  Alabama      Baldwin  2008  2008/01003       81413
# 2     1005  Alabama      Barbour  2008  2008/01005       11630
# 3     1007  Alabama         Bibb  2008  2008/01007        8644
# 4     1009  Alabama       Blount  2008  2008/01009       24267
# ...    ...      ...          ...   ...         ...         ...
# 3150  2037   Alaska  District 37  2016  2016/02037        5062
# 3151  2038   Alaska  District 38  2016  2016/02038        5095
# 3152  2039   Alaska  District 39  2016  2016/02039        5639
# 3153  2040   Alaska  District 40  2016  2016/02040        4610
# 3154  2099   Alaska  District 99  2016  2016/02099        5056
#
#       dem_vote_share  rep_vote_share  other_vote_share winning_party  ...  \
# 0           0.257730        0.736136          0.006133    Republican  ...
# ...

# %%
#delete rows without at least 13 data points (means all demog data is missing)
Final_ElectionDemogMerged=ElectionDemogMerged.dropna(thresh=13)

# %%
Final_ElectionDemogMerged
#now only 9346 rows of county data, removed 119 counties
# Out:
#        FIPS    state       county  year   FIPS/Year  totalvotes  \
# 0      1001  Alabama      Autauga  2008  2008/01001       23641
# 1      1003  Alabama      Baldwin  2008  2008/01003       81413
# 2      1005  Alabama      Barbour  2008  2008/01005       11630
# 3      1007  Alabama         Bibb  2008  2008/01007        8644
# 4      1009  Alabama       Blount  2008  2008/01009       24267
# ...     ...      ...          ...   ...         ...         ...
# 3112  56043  Wyoming     Washakie  2016  2016/56043        3814
# 3113  56045  Wyoming       Weston  2016  2016/56045        3526
# 3126   2013   Alaska  District 13  2016  2016/02013        6533
# 3129   2016   Alaska  District 16  2016  2016/02016        7436
# 3133   2020   Alaska  District 20  2016  2016/02020        7140
#
#       dem_vote_share  rep_vote_share  other_vote_share winning_party  ...  \
# 0           0.257730        0.736136          0.006133    Republican  ...
# ...

# %%
# Make Sure FIPS are 5 Digits
# Make Int FIPS a String
Final_ElectionDemogMerged['FIPS']= Final_ElectionDemogMerged['FIPS'].astype(str)
# Out:
# /Users/christydafonte/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
Final_ElectionDemogMerged.dtypes
# Out:
# FIPS                                                                       object
# state                                                                      object
# county                                                                     object
# year                                                                        int64
# FIPS/Year                                                                  object
#                                                                            ...
# % Civilian Population 18 Years and Over: Veteran: 18 to 64 Years          float64
# % Civilian Population 18 Years and Over: Veteran: 65 Years and Over       float64
# % Civilian Population 18 Years and Over: Nonveteran                       float64
# % Civilian Population 18 Years and Over: Nonveteran: 18 to 64 Years       float64
# % Civilian Population 18 Years and Over: Nonveteran: 65 Years and Over    float64
# Length: 69, dtype: object

# %%
#Change NaN to blank
Final_ElectionDemog = Final_ElectionDemogMerged.replace(np.nan, '')
Final_ElectionDemog
# Out:
#        FIPS    state       county  year   FIPS/Year  totalvotes  \
# 0      1001  Alabama      Autauga  2008  2008/01001       23641
# 1      1003  Alabama      Baldwin  2008  2008/01003       81413
# 2      1005  Alabama      Barbour  2008  2008/01005       11630
# 3      1007  Alabama         Bibb  2008  2008/01007        8644
# 4      1009  Alabama       Blount  2008  2008/01009       24267
# ...     ...      ...          ...   ...         ...         ...
# 3112  56043  Wyoming     Washakie  2016  2016/56043        3814
# 3113  56045  Wyoming       Weston  2016  2016/56045        3526
# 3126   2013   Alaska  District 13  2016  2016/02013        6533
# 3129   2016   Alaska  District 16  2016  2016/02016        7436
# 3133   2020   Alaska  District 20  2016  2016/02020        7140
#
#       dem_vote_share  rep_vote_share  other_vote_share winning_party  ...  \
# 0           0.257730        0.736136          0.006133    Republican  ...
# ...

# %%
# If FIPS String is 4 Digits Long- Add 0 to Beginning
Final_ElectionDemog.insert(len(Final_ElectionDemog.columns), 'Add Zero FIPS', '0' + Final_ElectionDemog['FIPS'])
Final_ElectionDemog.loc[Final_ElectionDemog['FIPS'].str.len()==4, 'FIPS'] = Final_ElectionDemog.loc[Final_ElectionDemog['FIPS'].str.len()==4, 'Add Zero FIPS']
del Final_ElectionDemog['Add Zero FIPS']

# %%
Final_ElectionDemog
# Out:
#        FIPS    state       county  year   FIPS/Year  totalvotes  \
# 0     01001  Alabama      Autauga  2008  2008/01001       23641
# 1     01003  Alabama      Baldwin  2008  2008/01003       81413
# 2     01005  Alabama      Barbour  2008  2008/01005       11630
# 3     01007  Alabama         Bibb  2008  2008/01007        8644
# 4     01009  Alabama       Blount  2008  2008/01009       24267
# ...     ...      ...          ...   ...         ...         ...
# 3112  56043  Wyoming     Washakie  2016  2016/56043        3814
# 3113  56045  Wyoming       Weston  2016  2016/56045        3526
# 3126  02013   Alaska  District 13  2016  2016/02013        6533
# 3129  02016   Alaska  District 16  2016  2016/02016        7436
# 3133  02020   Alaska  District 20  2016  2016/02020        7140
#
#       dem_vote_share  rep_vote_share  other_vote_share winning_party  ...  \
# 0           0.257730        0.736136          0.006133    Republican  ...
# ...

# %%
#making finished file an excel
path = 'Demographics/FinalDemographics_cleaned.xlsx'
Final_ElectionDemog.to_excel(path,index=False)
