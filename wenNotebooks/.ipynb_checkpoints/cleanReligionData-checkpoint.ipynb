# %%
import pandas as pd

# %%
# Get File
path = '../dataFiles/rawData/religion_by_county_2010.csv'
religion_data = pd.read_csv(path)
religion_data.head()
# Out:
#    FIPS          Qualifying Name  State  County State Abbreviation  \
# 0  1001  Autauga County, Alabama      1       1                 AL
# 1  1003  Baldwin County, Alabama      1       3                 AL
# 2  1005  Barbour County, Alabama      1       5                 AL
# 3  1007     Bibb County, Alabama      1       7                 AL
# 4  1009   Blount County, Alabama      1       9                 AL
#
#    Total Population 2010    Name of Area  Population (2010)  \
# 0                54571.0  Autauga County            54571.0
# 1               182265.0  Baldwin County           182265.0
# 2                27457.0  Barbour County            27457.0
# 3                22915.0     Bibb County            22915.0
# 4                57322.0   Blount County            57322.0
#
#    All Religious Congregations  All Religious Adherents  ...  \
# 0                        106.0                  36938.0  ...
# 1                        271.0                  96918.0  ...
# 2                         89.0                  15101.0  ...
# 3                         81.0                  11430.0  ...
# 4                        156.0                  37352.0  ...
#
#    Reconstructionist Judaism.1  Reform Judaism.1  Shinto.1  Sikh.1  \
# 0                          NaN               NaN       NaN     NaN
# 1                          NaN               NaN       NaN     NaN
# 2                          NaN               NaN       NaN     NaN
# 3                          NaN               NaN       NaN     NaN
# 4                          NaN               NaN       NaN     NaN
#
#    Swedenborgian Church.1  Tao.1  Union of Messianic Jewish Congregations.2  \
# 0                     NaN    NaN                                        NaN
# 1                     NaN    NaN                                        NaN
# 2                     NaN    NaN                                        NaN
# 3                     NaN    NaN                                        NaN
# 4                     NaN    NaN                                        NaN
#
#    Unitarian Universalist Association of Congregations.2  Unity Churches  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
#
#    Zoroastrian.1
# 0          0.005
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 758 columns]

# %%
# Make Sure FIPS are 5 Digits
# Make Int a String
religion_data['FIPS'] = religion_data['FIPS'].astype(str)
# If FIPS String is 4 Digits Long- Add 0 to Beginning
religion_data.loc[religion_data['FIPS'].str.len()==4, ]
# Out:
# FIPS                                                      object
# Qualifying Name                                           object
# State                                                      int64
# County                                                     int64
# State Abbreviation                                        object
# Total Population 2010                                    float64
# Name of Area                                              object
# Population (2010)                                        float64
# All Religious Congregations                              float64
# All Religious Adherents                                  float64
# All Religious Adherence Rate of Total Population         float64
# Total Congregations - Major Religions                    float64
# Evangelical Protestant Congregations                     float64
# Black Protestant Congregations                           float64
# Mainline Protestant Congregations                        float64
# Catholic Congregations                                   float64
# Orthodox Congregations                                   float64
# Other Congregations                                      float64
# Total Adherents - Major Religions                        float64
# Evangelical Protestant Congregations.1                   float64
# Black Protestant Congregations.1                         float64
# Mainline Protestant Congregations.1                      float64
# Catholic Congregations.1                                 float64
# Orthodox Congregations.1                                 float64
# Other Congregations.1                                    float64
# Major Religions - Adherence Rate (% of Population)       float64
# Evangelical Protestant                                   float64
# Black Protestant                                         float64
# Mainline Protestant                                      float64
# Catholic                                                 float64
#                                                           ...
# Other Adherence Rate (% of Population)                   float64
# Association of Messianic Congregations.2                 float64
# Baha'i.1                                                 float64
# Buddhism, Mahayana.1                                     float64
# Buddhism, Theravada.1                                    float64
# Buddhism, Vajrayana.1                                    float64
# Church of Christ, Scientist.1                            float64
# Church of Jesus Christ of Latter-day Saints.1            float64
# Community of Christ.1                                    float64
# Conservative Judaism.1                                   float64
# Hindu, Indian-American Hindu Temple Association.1        float64
# Hindu, Post Renaissance.1                                float64
# Hindu, Renaissance.1                                     float64
# Hindu, Traditional Temples.1                             float64
# Jain.1                                                   float64
# Jehovah's Witnesses.1                                    float64
# Muslim estimate.1                                        float64
# National Spiritualist Association of Churches.1          float64
# New Apostolic Church of North America                    float64
# Orthodox Judaism.1                                       float64
# Reconstructionist Judaism.1                              float64
# Reform Judaism.1                                         float64
# Shinto.1                                                 float64
# Sikh.1                                                   float64
# Swedenborgian Church.1                                   float64
# Tao.1                                                    float64
# Union of Messianic Jewish Congregations.2                float64
# Unitarian Universalist Association of Congregations.2    float64
# Unity Churches                                           float64
# Zoroastrian.1                                            float64
# Length: 758, dtype: object
